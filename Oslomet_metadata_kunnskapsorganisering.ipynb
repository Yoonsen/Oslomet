# %% [markdown]
# # Oslomet oktober 2018

# %% [markdown]
# Importer ressurser

# %%
import requests

# hent Python-modulen nbtext.py fra Github
nba = requests.get("https://raw.githubusercontent.com/Yoonsen/Modules/master/nbtext.py").text
with open('nbtext.py','w', encoding='UTF-8') as pyfile:
    pyfile.write(nba)

# hent nbpictures.py fra Github
nbb = requests.get("https://raw.githubusercontent.com/Yoonsen/Modules/master/nbpictures.py").text
with open('nbpictures.py','w', encoding='UTF-8') as pyfile:
    pyfile.write(nbb)

import nbtext as nb
import nbpictures as pct

# %% [markdown]
# # Nasjonalbiblioteket og digitalisering
#
# * Digitaliseringsarbeidet startet for alvor i 2006
# * Metadata for bøker fra Nasjonalbibliografien, og nye metadataformat for nye medier, som film og lyd.
# * Bokhylla-avtalen fra 2012. Alle bøker publisert før 2000 er tilgjengelig på [nb.no](https://www.nb.no)
# * Fra 2017 er bøkene også gjort tilgjengelig for forskning gjennom ikke-konsumerbar bruk

# %% [markdown]
# # Kunnskapsorganisering
#
# ### Hva er kunnskap?
#
# * [Wikipedia](https://en.wikipedia.org/wiki/Knowledge)
# * [Stanford encyclopedia om epistemologi](https://plato.stanford.edu/entries/epistemology/)
# * [Stanfor encyclopdia kunnskap](https://plato.stanford.edu/entries/knowledge-analysis/)
#
# En viktig forskjell på kunnskap og informasjon er materialiteten. Vi kan se litt på egenskaper til de ordene som brukes.
# Her er noen grammatiske forskjeller på kunnskap og informasjon:
#
#     Informasjonen/?kunnskapen ble sendt med post.
#     Ola har informasjon/?kunnskap om at jorda er flat. (? fordi jorda ikke er det)
#
# Det å ha kunnskap, eller vite noe, impliserer sannhet (vite er et faktuelt verb) på samme måte som beklage:
#
#     Det at "Ola vet/beklager at det regner", betyr at det regner.
#
# Kunnskap er også forskjellig fra informasjon - i tillegg til at informasjon kan være usann eller sann (på samme måte som påstander) vil kunnskap i større grad oppstå gjennom slutninger, pr.definisjon er kunnskap sann (så når noe rokker ved kunnskapen er det mye som ryker i samme slengen): samtidig som du får informasjon om en ting, kan du få kunnskap om mye mer:
#
# Du vet at melken befinner seg i ett av tre kjøleskap A, B eller C, og du har fått verifisert informasjon om at det er i enten A eller B. Så får du (verifisert) informasjon om at melken befinner seg i B eller C. Fra det kan du slutte, eller få kunnskapen om, at melken befinner seg i B.  Merk at du ikke har noe direkte informasjon om at melken er i B, men ved å kombinere informasjonen fra tidligere (A eller B) og (B eller C) kan du få _kunnskap_ som ikke ligger i noen informasjonsbitene, men som er et resultat av å kombinere dem.
#
# Mens informasjon kan flyttes, slettes, komme på avveie etc., har ikke kunnskap noen av de egenskapene. Selv ikke når kunnskapen og informasjonen har det samme innholdet, som når du får en lapp hvor det står at Galdhøpiggen er 2400 meter høy. Kunnskapen fra informasjonen er distinkt fra informasjonen selv. Om noen gir deg lappen, har du fått informasjonen, men kunnskapen har du ikke fått før du leser lappen og forstår den. Altså, man kan si at "informasjonen er overført" etter å gitt noen en slik lapp, men du kan ikke uten videre si at "kunnskapen er overført" etter samme handling.
#
# En annen grammatisk egenskap ved kunnskap ligger i måten den overføres på, at kunnskap har samme egenskap som hodepine i:
#
#     Han ga henne hodepine/kunnskap
#     *?Han ga hodepine/kunnskap til henne
#
# I motsetning til informasjon og bøker, der
#
#     Hun ga barna bøker/informasjonen
#
# er like bra som:
#
#     Hun ga bøker/informasjonen til barna
#
# Så vi kan si at kunnskap er privat og konstitueres av den enkelte, mens informasjon er åpen og offentlig.

# %% [markdown]
# # Metadata for objekter

# %%
nb.dewey(739)
# Out:
# {'1': ['7', 'Kunst og fritid'],
#  '2': ['73', 'Skulptur; keramisk kunst og metallkunst'],
#  '3': ['739', 'Metallkunst']}

# %%
xmlpretty(nb.metadata_xml(2008091603022))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <html>
#  <body>
#   <record xmlns="http://www.loc.gov/MARC21/slim">
#    <leader>
#     nam  22     uu 4500
#    </leader>
#    <controlfield tag="001">
#     999217110854702202
#    </controlfield>
#    <controlfield tag="003">
#     nb.bibsys.no
#    </controlfield>
#    <controlfield tag="005">
#     20130806121049.0
#    </controlfield>
#    <controlfield tag="008">
#     130806
#                         s
#                             xx#||||| |||||||||||nob||
#    </controlfield>
#    <datafield ind1=" " ind2=" " tag="040">
#     <subfield code="a">
#      NO-OsNB
#     </subfield>
#    </datafield>
#    <datafield ind1="1" ind2="0" tag="245">
#     <subfield code="a">
#      Ringen sluttet
#     </subfield>
#     <subfield code="b">
#      roman
#     </subfield>
#     <subfield code="c">
#      Knut Hamsun
#     </subfield>
#    </datafield>
#    <datafield ind1="1" ind2=" " tag="700">
#     <subfield code="a">
#      Hamsun, Knut
#     </subfield>
#     <subfield code="d">
#      1859-1952
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2="7" tag="655">
#     <subfield code="a">
#      unknown
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="260">
#     <subfield code="a">
#      Oslo
#     </subfield>
#     <subfield code="b">
#      Gyldendal
#     </subfield>
#     <subfield code="c">
#      1936
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="300">
#     <subfield code="a">
#      2 b. i 1 (206, 235 s.)
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="">
#     <subfield code="a">
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="500">
#     <subfield code="a">
#      Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2009-04-04
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="856">
#     <subfield code="u">
#      http://urn.nb.no/URN:NBN:no-nb_digibok_2008091603022
#     </subfield>
#     <subfield code="3">
#      Fulltekst NB digitalisert
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="856">
#     <subfield code="u">
#      http://urn.nb.no/URN:NBN:no-nb_digibok_2008091603022
#     </subfield>
#     <subfield code="3">
#      electronic resource
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="852">
#     <subfield code="a">
#      NO-0183300
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="852">
#     <subfield code="a">
#      NO-0030100
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="852">
#     <subfield code="a">
#      NO-0183300
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="856">
#     <subfield code="u">
#      http://urn.nb.no/URN:NBN:no-nb_digibok_2008091603022
#     </subfield>
#    </datafield>
#   </record>
#  </body>
# </html>

# %%
find_urls('Ibsen', mediatype='bok')
# Out:
# []

# %%
xmlpretty(metadata_mods('20170711_00089_NB_MIT_GNR_14076'))
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <html>
#  <body>
#   <mods xmlns="http://www.loc.gov/mods/v3" xmlns:fn="http://www.w3.org/2005/xpath-functions" xmlns:mods="http://www.loc.gov/mods/v3" xmlns:nbmodsext="http://www.nb.no/NBModsExtension/v1" xmlns:xl="http://www.w3.org/1999/xlink" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
#    <titleinfo>
#     <title>
#      [Kvinner]
#     </title>
#    </titleinfo>
#    <name type="corporate">
#     <namepart>
#      Mittet &amp; Co. AS
#     </namepart>
#     <role>
#      <roleterm authority="mavis" type="text">
#       Fotograf (stillbilder)
#      </roleterm>
#      <roleterm authority="mavis" type="code">
#       FTG
#      </roleterm>
#     </role>
#     <nameidentifier>
#      mavis.nb.no:/Organisation/key/17222-1
#     </nameidentifier>
#    </name>
#    <name type="personal">
#     <namepart type="family">
#      Neupert
#     </namepart>
#     <namepart type="given">
#      Hermann Christian
#     </namepart>
#     <namepart>
#      Neupert, Hermann Christian
#     </namepart>
#     <namepart type="date">
#      1875-1941
#     </namepart>
#     <role>
#      <roleterm authority="mavis" type="text">
#       Fotograf (stillbilder)
#      </roleterm>
#      <roleterm authority="mavis" type="code">
#       FTG
#      </roleterm>
#     </role>
#     <nameidentifier>
#      mavis.nb.no:/Person/key/20269-1
#     </nameidentifier>
#    </name>
#    <typeofresource>
#     still image
#    </typeofresource>
#    <genre>
#     Fotografi
#    </genre>
#    <origininfo>
#     <place>
#      <placeterm type="text">
#       Norge
#      </placeterm>
#      <placeterm authority="iso3166" type="code">
#       NO
#      </placeterm>
#     </place>
#     <datecreated encoding="w3cdtf">
#      1900-07
#     </datecreated>
#    </origininfo>
#    <physicaldescription>
#     <form>
#      Digitalt
#     </form>
#     <form>
#      Fotografier
#     </form>
#    </physicaldescription>
#    <abstract>
#     minnefotografi, personer, portrett, (Dagny Neupert?)
#    </abstract>
#    <location>
#     <url>
#      URN:NBN:no-nb_digifoto_20170711_00089_NB_MIT_GNR_14076
#     </url>
#    </location>
#    <identifier type="uri">
#     http://urn.nb.no/URN:NBN:no-nb_digifoto_20170711_00089_NB_MIT_GNR_14076
#    </identifier>
#    <identifier type="urn">
#     URN:NBN:no-nb_digifoto_20170711_00089_NB_MIT_GNR_14076
#    </identifier>
#    <identifier type="oldoaiid">
#     oai:mavis.nb.no:634615
#    </identifier>
#    <recordinfo>
#     <recordcontentsource>
#      Mavis
#     </recordcontentsource>
#     <recordidentifier source="mavis.nb.no">
#      /TitleWork/key/634615
#     </recordidentifier>
#    </recordinfo>
#    <note>
#     Påskrift eske: Juli 1900 - Aug 1905
# Påskrift konvolutt: Juli 1900
# Påskrift negativ: Juli 1900
#    </note>
#    <extension>
#     <nbmodsext:nbtypeofresource sound="N">
#      Fotografi
#     </nbmodsext:nbtypeofresource>
#     <nbmodsext:nbreformattingquality>
#      Sikringseksemplar
#     </nbmodsext:nbreformattingquality>
#     <nbmodsext:accessproject>
#      FE
#     </nbmodsext:accessproject>
#     <nbmodsext:accesscollection>
#      295
#     </nbmodsext:accesscollection>
#    </extension>
#    <identifier type="sesamid">
#     b2bd548600bacb3bdfdb66027ec5ffc4
#    </identifier>
#    <identifier type="oaiid">
#     oai:mavis.nb.no:/TitleWork/key/634615
#    </identifier>
#   </mods>
#  </body>
# </html>
