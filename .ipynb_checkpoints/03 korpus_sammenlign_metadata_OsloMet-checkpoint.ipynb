# %% [markdown]
# # Undersøk korpus med metadata
#
# Notebook for å undersøke korpus med metadata.
#
# En viktig metode i undersøkelse av metadata og tekster er grafer og nettverk.
#
# * [Wikipedia](

# %%
import dhlab.module_update as mu
import dhlab.nbtext as nb
import dhlab.token_map as tm
import dhlab.graph_networkx_louvain as gnl

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# Kommandoen for å lage et korpus er *Corpus()* som bygger et korpus av tekster som sammenlignes med en referanse. I det her eksemplet bygges referansen samtidig, men i et ideelt tilfelle kan vi ønske å la referansen være ferdigbygd et sted.

# %%
bøker = nb.book_corpus(
    period=(1950, 2010),
    #title='%',
    #subject='krig',
    ddk='335%', limit=300)

# %%
bøker
# Out:
#                urn              author  \
# 0    2015062308020   Dimitrov, Georgij
# 1    2012020104070         Lenin, V.I.
# 2    2014021706028     Ustvedt, Yngvar
# 3    2015042708004       Seeger, Heinz
# 4    2012090708113    Bårtveit, Harald
# 5    2007060404018
# 6    2012022008185    Deutscher, Isaac
# 7    2016102848601    Apeland, Nils M.
# 8    2013041806068     Kleven, Hans I.
# 9    2012052508001         Bingen, Jon
# 10   2012010508040         Lenin, V.I.
# 11   2007062701030        Steigan, Pål
# 12   2016082408022    Bakunin, Michail
# 13   2007092401072       Nilsen, Fritz
# 14   2011011906018   Engels, Friedrich
# 15   2013040308072
# 16   2012110108069          Marx, Karl
# 17   2011051020005
# 18   2007071101055          Marx, Karl
# 19   2007072601038  Rjazanov, David B.
# 20   2012091808096    Milejkovskij, A.
# 21   2012022008032         Lenin, V.I.
# 22   2007041801037      Elster, Torolf
# 23   2009011404101     Anckar, Herbert
# 24   2007112601070          Marx, Karl
# 25   2007071900090      Fischer, Ernst
# 26   2012010508004      Fischer, Ernst
# 27   2011102508136         Lenin, V.I.
# 28   2007080101031  Nyerere, Julius K.
# 29   2014121608106     Kalheim, Ragnar
# ..             ...                 ...
# 149  2014090808102
# 150  2016112908115
# 151  2007061801037   Glucksmann, André
# 152  2013041608042         Lenin, V.I.
# 153  2014112508038          Skard, Jon
# 154  2006111401013      Lukács, György
# 155  2014030707099         Mao, Zedong
# 156  2007061100051  Kolakowski, Leszek
# 157  2008103104079         Lenin, V.I.
# 158  2016062708103          Marx, Karl
# 159  2007060501049       Brandt, Willy
# 160  2012033008104          Skard, Jon
# 161  2014032808055        Stalin, I.V.
# 162  2012011808228
# 163  2010081608018     Kleven, Hans I.
# 164  2014111008043        Stalin, I.V.
# 165  2006110601056     Ustvedt, Yngvar
# 166  2010100608047          Marx, Karl
# 167  2013041906043     Kleven, Hans I.
# 168  2011052308041
# 169  2013040907017         Gorz, André
# 170  2007072300076
# 171  2007072400117       Gravem, Peder
# 172  2007072400107      Svensson, Jörn
# 173  2012062805029     Hellesøy, Anton
# 174  2007072704017         Elster, Jon
# 175  2008052804073    Berntsen, Harald
# 176  2013041807076   Broyelle, Claudie
# 177  2013102406054
# 178  2007073004013         Lenin, V.I.
#
#                                                  title  year
# 0         Om enhetsfrontens og folkefrontens problemer  1970
# 1    Nasjonal politikk og proletarisk internasjonal...  1971
# 2                                            Karl Marx  1976
# 3                          Marxistisk politisk økonomi  1973
# 4                                 Politikk og ritualer  1975
# 5                              Strategi for sosialisme  1965
# 6                  Lenins barndom ; Marxisme i vår tid  1972
# 7                  Communist front youth organizations  1959
# 8                                     herskende klasse  1977
# 9                            Nymarxist i norsk andedam  1979
# 10                 Utopisk og vitenskapelig sosialisme  1970
# 11                                     Svar på tiltale  1982
# 12   Det revolusjonære spørsmål : føderalisme, sosi...  2002
# 13                          Norsk sosialisme - hva nå?  1991
# 14      Sosialismens utvikling fra utopi til vitenskap  1970
# 15                                    Utopi og økonomi  1984
# 16                                           Kapitalen  1983
# 17                          Les til sommerleirene 1978  1978
# 18                          Det kommunistiske manifest  1984
# 19          Marx og Engels (ikke bare) for nybegynnere  1977
# 20           Krisen i den borgerlige politiske økonomi  1974
# 21                          Kultur og kulturrevolusjon  1972
# 22                                  Inn i en ny verden  1961
# 23                              Hva vil syndikalismen?  1978
# 24                              Det beste av Karl Marx  1992
# 25                               Hva Lenin egentlig sa  1971
# 26                                Hva Marx egentlig sa  1970
# 27                                       Lenin om Marx  1970
# 28                               Sosialisme i Tanzania  1970
# 29                                   Alt for mennesket  1963
# ..                                                 ...   ...
# 149                                Om å lese Kapitalen  1983
# 150                          Sosialiserings-spørsmålet  1961
# 151                       Kokkepiken og menneskeeteren  1978
# 152    Imperialismen som kapitalismens høyeste stadium  1969
# 153                                           AKP(m-l)  1977
# 154                       Historie og klassebevissthet  1971
# 155                                     Om motsigelsen  1978
# 156                          Mennesket uten alternativ  1966
# 157    Imperialismen som kapitalismens høyeste stadium  2001
# 158                         Det kommunistiske manifest  1969
# 159                         Brev og samtaler 1972-1975  1976
# 160                  Slik arbeider marxist-leninistene  1973
# 161                              Spørsmål i leninismen  1976
# 162            Leve det proletariske diktaturets seier  1971
# 163                                    Klassesamfunnet  1998
# 164  Marxismen og det nasjonale og koloniale spørsm...  1978
# 165                                          Opprørere  1973
# 166                                          Kapitalen  1995
# 167                                   herskende klasse  1976
# 168                 Reis kampen blant arbeiderkvinnene  1975
# 169                           Farvel til proletariatet  1981
# 170                                Sosialimperialismen  1975
# 171                             Kristendom og marxisme  1977
# 172                      Du skal ta ledelsen og makten  1977
# 173            Loven om profittratens fallende tendens  1978
# 174                                       Om utbytting  1977
# 175  historiske materialismen og dens historiske be...  1976
# 176                                    Steinenes glede  1980
# 177                Berlin-konferansen og våre oppgaver  1977
# 178           "Radikalismen", kommunismens barnesykdom  1969
#
# [179 rows x 4 columns]

# %% [markdown]
# ## Undersøk forskjeller
#
# Her samler vi sammen alle bøkene i korpus og summerer. Men først la oss se på en del av korpuset som en dokument term matrise

# %%
# tar de fem første og henter frekvensene for alle bøkene

bøker_dtm = nb.get_corpus_text(nb.pure_urn(bøker)[:5])

# %%
bøker_dtm
# Out:
#                2015062308020  2012020104070  2014021706028  2015042708004  \
# ,                     2971.0         2999.0          400.0          897.0
# og                    2449.0         1967.0          378.0          571.0
# .                     2395.0         2096.0          472.0         1020.0
# i                     2029.0         2001.0          277.0          539.0
# av                    1314.0         1058.0          184.0          532.0
# som                   1274.0         1165.0          201.0          427.0
# de                    1240.0          987.0          105.0          236.0
# å                     1236.0          975.0          144.0          188.0
# det                   1226.0         1512.0          216.0          233.0
# den                   1204.0         1123.0          162.0          404.0
# for                   1060.0          909.0          127.0          291.0
# er                    1057.0         1109.0          133.0          339.0
# til                   1055.0          873.0          178.0          348.0
# en                     992.0         1075.0          135.0          216.0
# på                     718.0          598.0          123.0          154.0
# at                     690.0          765.0           98.0          161.0
# ikke                   688.0          703.0          108.0          122.0
# med                    625.0          505.0           93.0          119.0
# mot                    621.0          259.0           12.0           19.0
# »                      523.0         1080.0           94.0           61.0
# har                    496.0          431.0           58.0          110.0
# om                     336.0          500.0           78.0           59.0
# vi                     335.0          245.0           24.0           20.0
# må                     326.0          134.0           17.0           56.0
# seg                    321.0          322.0           65.0           76.0
# et                     313.0          430.0           64.0           90.0
# fra                    303.0          338.0           34.0           35.0
# Den                    294.0          152.0           30.0           76.0
# alle                   294.0          213.0           55.0           51.0
# fascismen              277.0            NaN            NaN            NaN
# ...                      ...            ...            ...            ...
# øste                     NaN            NaN            1.0            NaN
# østerrikere              NaN            1.0            NaN            NaN
# østerrikerne             NaN            3.0            NaN            NaN
# østeuropeiske            NaN            NaN            1.0            NaN
# østeuropéisk             NaN            1.0            NaN            NaN
# østlige                  NaN            2.0            NaN            NaN
# østligste                NaN            1.0            NaN            NaN
# øverst                   NaN            1.0            NaN            NaN
# øvet                     NaN            1.0            1.0            NaN
# øyemedet                 NaN            NaN            NaN            1.0
# øyensynlig               NaN            1.0            NaN            NaN
# übalanse                 NaN            NaN            NaN            NaN
# übarmhjertig             NaN            1.0            2.0            NaN
# übegrenset               NaN            1.0            NaN            NaN
# übegrunnet               NaN            2.0            NaN            NaN
# übehagelig               NaN            4.0            1.0            NaN
# übehøvlede               NaN            1.0            NaN            NaN
# übeskrivelig             NaN            NaN            1.0            NaN
# übestemt                 NaN            1.0            NaN            NaN
# übestemte                NaN            2.0            NaN            NaN
# übestridt                NaN            NaN            NaN            NaN
# übestridte               NaN            NaN            NaN            NaN
# übetalt                  NaN            NaN            NaN            3.0
# übetingede               NaN            3.0            NaN            NaN
# übetydelig               NaN            NaN            NaN            NaN
# übevisst                 NaN            1.0            NaN            NaN
# übevisste                NaN            1.0            NaN            NaN
# übrytelig                NaN            2.0            NaN            NaN
# übytting                 NaN            NaN            NaN            1.0
# €                        NaN            NaN            NaN            NaN
#
#                2012090708113
# ,                     1617.0
# og                     851.0
# .                     2161.0
# i                      805.0
# av                     734.0
# som                    645.0
# de                     341.0
# å                      556.0
# det                    396.0
# den                    441.0
# for                    516.0
# er                     413.0
# til                    450.0
# en                     443.0
# på                     318.0
# at                     343.0
# ikke                   223.0
# med                    203.0
# mot                     79.0
# »                        2.0
# har                    148.0
# om                     162.0
# vi                      20.0
# må                      85.0
# seg                     76.0
# et                     177.0
# fra                    152.0
# Den                    102.0
# alle                    30.0
# fascismen                NaN
# ...                      ...
# øste                     NaN
# østerrikere              NaN
# østerrikerne             NaN
# østeuropeiske            NaN
# østeuropéisk             NaN
# østlige                  NaN
# østligste                NaN
# øverst                   NaN
# øvet                     NaN
# øyemedet                 NaN
# øyensynlig               NaN
# übalanse                 1.0
# übarmhjertig             NaN
# übegrenset               NaN
# übegrunnet               NaN
# übehagelig               NaN
# übehøvlede               NaN
# übeskrivelig             NaN
# übestemt                 1.0
# übestemte                NaN
# übestridt                1.0
# übestridte               1.0
# übetalt                  NaN
# übetingede               1.0
# übetydelig               1.0
# übevisst                 NaN
# übevisste                NaN
# übrytelig                NaN
# übytting                 NaN
# €                        1.0
#
# [22791 rows x 5 columns]

# %% [markdown]
# Et varmekart gjør det enklere å spotte likhet og variasjon i tallene.

# %%
nb.heatmap(bøker_dtm.head(50), color='#045599')
# Out:
# <style  type="text/css" >
#     #T_c9547b00_efa2_11e9_9137_000acd2bfab2row0_col0 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row0_col1 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row0_col2 {
#             background-color:  #276da9;
#             color:  #f1f1f1;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row0_col3 {
#             background-color:  #1f68a5;
#             color:  #f1f1f1;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row0_col4 {
#             background-color:  #3d7db2;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row1_col0 {
#             background-color:  #2e72ac;
#             color:  #f1f1f1;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row1_col1 {
#             background-color:  #528cbc;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row1_col2 {
#             background-color:  #3074ad;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row1_col3 {
#             background-color:  #679bc6;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row1_col4 {
#             background-color:  #8db5d7;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row2_col0 {
#             background-color:  #3275ae;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row2_col1 {
#             background-color:  #4885b8;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row2_col2 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row2_col3 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row2_col4 {
#             background-color:  #045599;
#             color:  #f1f1f1;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row3_col0 {
#             background-color:  #4f8abb;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row3_col1 {
#             background-color:  #4f8abb;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row3_col2 {
#             background-color:  #6196c3;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row3_col3 {
#             background-color:  #6e9fc9;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row3_col4 {
#             background-color:  #92b8d9;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row4_col0 {
#             background-color:  #89b2d5;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row4_col1 {
#             background-color:  #96bbdb;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row4_col2 {
#             background-color:  #8eb6d7;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row4_col3 {
#             background-color:  #70a1c9;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row4_col4 {
#             background-color:  #9abedc;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row5_col0 {
#             background-color:  #8cb4d6;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row5_col1 {
#             background-color:  #8eb6d7;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row5_col2 {
#             background-color:  #85b0d3;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row5_col3 {
#             background-color:  #87b1d4;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row5_col4 {
#             background-color:  #a3c4e0;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row6_col0 {
#             background-color:  #8fb6d7;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row6_col1 {
#             background-color:  #9cbfdd;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row6_col2 {
#             background-color:  #b4d1e8;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row6_col3 {
#             background-color:  #b2cfe7;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row6_col4 {
#             background-color:  #c3daee;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row7_col0 {
#             background-color:  #8fb6d7;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row7_col1 {
#             background-color:  #9dc0dd;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row7_col2 {
#             background-color:  #a1c3df;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row7_col3 {
#             background-color:  #bcd6ec;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row7_col4 {
#             background-color:  #adcbe5;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row8_col0 {
#             background-color:  #90b7d8;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row8_col1 {
#             background-color:  #74a3cb;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row8_col2 {
#             background-color:  #7eabd0;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row8_col3 {
#             background-color:  #b3cfe7;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row8_col4 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row9_col0 {
#             background-color:  #92b8d9;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row9_col1 {
#             background-color:  #92b8d9;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row9_col2 {
#             background-color:  #99bddc;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row9_col3 {
#             background-color:  #8db5d6;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row9_col4 {
#             background-color:  #b8d3ea;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row10_col0 {
#             background-color:  #9dc0de;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row10_col1 {
#             background-color:  #a2c4e0;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row10_col2 {
#             background-color:  #aac9e3;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row10_col3 {
#             background-color:  #a5c6e1;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row10_col4 {
#             background-color:  #b0cde6;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row11_col0 {
#             background-color:  #9dc0de;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row11_col1 {
#             background-color:  #93b9d9;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row11_col2 {
#             background-color:  #a6c7e2;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row11_col3 {
#             background-color:  #9bbfdd;
#             color:  #000000;
#         }    #T_c9547b00_efa2_11e9_9137_000acd2bfab2row11_col4 {
#             background-color:  #bcd6eb;
#             color:  #0

# %% [markdown]
# Tre hundre bøker tar en tid å laste ned og telle opp lokalt så vi teller på server med passende kommando:

# %%
bøker_agg = nb.aggregate_urns(nb.pure_urn(bøker))

# %% [markdown]
# Så konverteres listen over ord og tall til en dataramme

# %%
bøker_df = nb.frame_sort(nb.frame(bøker_agg, 'count'))

# %% [markdown]
# For referanse henter vi ut de 50000 mest frekvente ordene i bokhylla.

# %%
totals = nb.frame(nb.totals(50000), 'tot')

# %% [markdown]
# Sånn ser frekvensene ut for bøkene

# %%
bøker_df.head(20)
# Out:
#        count
# ,     485488
# .     431913
# og    299126
# i     277009
# som   197925
# av    189300
# den   179799
# det   177978
# er    168222
# til   152398
# en    146932
# for   126346
# å     119078
# de    119036
# at    114580
# på     95127
# ikke   86514
# »      86007
# «      83787
# med    80171

# %% [markdown]
# .. og sånn for bokhylla

# %%
totals.head(20)
# Out:
#             tot
# .    1265723110
# ,    1105303412
# og    543432056
# i     460246057
# det   273411583
# som   265144740
# til   254500136
# er    248764786
# av    235180661
# en    231631623
# på    205990369
# for   202452659
# at    199527660
# -     195716474
# å     184201667
# med   182427175
# )     172258528
# var   153392365
# ?     151860120
# den   151216998

# %% [markdown]
# Vi finner forskjellen ved å dividere den ene på den andre:

# %%
forskjell = bøker_df['count']/totals['tot']

# %% [markdown]
# Tallene må sorteres, de høyeste tolkes til å være de mest relevante

# %%
bøker_typiske_ord = nb.frame_sort(nb.frame(forskjell, 'ratio'))
bøker_typiske_ord.head(50)
# Out:
#                      ratio
# proletariatets    0.149739
# proletariatet     0.145173
# Engels            0.099062
# kapitalens        0.098061
# kapitalistiske    0.083680
# Marx              0.076045
# sosialismen       0.074794
# kapitalismen      0.074625
# marxismen         0.067131
# borgerskapet      0.064280
# borgerskapets     0.061855
# arbeideren        0.060015
# kapitalismens     0.056702
# arbeiderklassens  0.056064
# Lenin             0.054539
# Lenins            0.054271
# diktatur          0.053092
# marxistiske       0.050151
# revolusjonære     0.048577
# Kapitalen         0.047969
# utbytting         0.047947
# kapitalistisk     0.046798
# sosialistiske     0.046419
# arbeiderklassen   0.044652
# reaksjonære       0.043502
# sosialisme        0.041650
# revolusjonær      0.040483
# kommunistiske     0.040472
# dialektiske       0.035996
# revolusjonens     0.035095
# kapitalisme       0.034840
# NKP               0.034010
# kommunismen       0.034001
# sosialistisk      0.033829
# massene           0.031288
# kapitalen         0.030761
# herskende         0.030497
# kommunisme        0.030207
# arbeidsdelingen   0.028718
# klasses           0.028618
# arbeidende        0.028480
# profitt           0.028361
# materialisme      0.028066
# arbeidsprosessen  0.027724
# samfunnsmessige   0.027595
# sosialister       0.027144
# borgerlige        0.027016
# dialektikk        0.026760
# marxistisk        0.026723
# arbeidsdagen      0.026396

# %% [markdown]
# Som ordsky

# %%
nb.cloud(bøker_typiske_ord.head(50))

# %% [markdown]
# # Metadata for korpuset kan raskt sjekkes
#
# Pass på at ikke korpuset er for stort (mange tusen).

# %%
nb.frame(nb.metadata(nb.pure_urn(bøker)), 'urn forfatter år tittel subtittel forlag sjanger sesamid språk'.split())
# Out:
#                urn           forfatter    år  \
# 0    2015062308020   Dimitrov, Georgij  1970
# 1    2012020104070         Lenin, V.I.  1971
# 2    2014021706028     Ustvedt, Yngvar  1976
# 3    2015042708004       Seeger, Heinz  1973
# 4    2012090708113    Bårtveit, Harald  1975
# 5    2007060404018                      1965
# 6    2012022008185    Deutscher, Isaac  1972
# 7    2016102848601    Apeland, Nils M.  1959
# 8    2013041806068     Kleven, Hans I.  1977
# 9    2012052508001         Bingen, Jon  1979
# 10   2012010508040         Lenin, V.I.  1970
# 11   2007062701030        Steigan, Pål  1982
# 12   2016082408022    Bakunin, Michail  2002
# 13   2007092401072       Nilsen, Fritz  1991
# 14   2011011906018   Engels, Friedrich  1970
# 15   2013040308072                      1984
# 16   2012110108069          Marx, Karl  1983
# 17   2011051020005                      1978
# 18   2007071101055          Marx, Karl  1984
# 19   2007072601038  Rjazanov, David B.  1977
# 20   2012091808096    Milejkovskij, A.  1974
# 21   2012022008032         Lenin, V.I.  1972
# 22   2007041801037      Elster, Torolf  1961
# 23   2009011404101     Anckar, Herbert  1978
# 24   2007112601070          Marx, Karl  1992
# 25   2007071900090      Fischer, Ernst  1971
# 26   2012010508004      Fischer, Ernst  1970
# 27   2011102508136         Lenin, V.I.  1970
# 28   2007080101031  Nyerere, Julius K.  1970
# 29   2014121608106     Kalheim, Ragnar  1963
# ..             ...                 ...   ...
# 149  2014090808102                      1983
# 150  2016112908115                      1961
# 151  2007061801037   Glucksmann, André  1978
# 152  2013041608042         Lenin, V.I.  1969
# 153  2014112508038          Skard, Jon  1977
# 154  2006111401013      Lukács, György  1971
# 155  2014030707099         Mao, Zedong  1978
# 156  2007061100051  Kolakowski, Leszek  1966
# 157  2008103104079         Lenin, V.I.  2001
# 158  2016062708103          Marx, Karl  1969
# 159  2007060501049       Brandt, Willy  1976
# 160  2012033008104          Skard, Jon  1973
# 161  2014032808055        Stalin, I.V.  1976
# 162  2012011808228                      1971
# 163  2010081608018     Kleven, Hans I.  1998
# 164  2014111008043        Stalin, I.V.  1978
# 165  2006110601056     Ustvedt, Yngvar  1973
# 166  2010100608047          Marx, Karl  1995
# 167  2013041906043     Kleven, Hans I.  1976
# 168  2011052308041                      1975
# 169  2013040907017         Gorz, André  1981
# 170  2007072300076                      1975
# 171  2007072400117       Gravem, Peder  1977
# 172  2007072400107      Svensson, Jörn  1977
# 173  2012062805029     Hellesøy, Anton  1978
# 174  2007072704017         Elster, Jon  1977
# 175  2008052804073    Berntsen, Harald  1976
# 176  2013041807076   Broyelle, Claudie  1980
# 177  2013102406054                      1977
# 178  2007073004013         Lenin, V.I.  1969
#
#                                                 tittel  \
# 0         Om enhetsfrontens og folkefrontens problemer
# 1    Nasjonal politikk og proletarisk internasjonal...
# 2                                            Karl Marx
# 3                          Marxistisk politisk økonomi
# 4                                 Politikk og ritualer
# 5                              Strategi for sosialisme
# 6                  Lenins barndom ; Marxisme i vår tid
# 7                  Communist front youth organizations
# 8                                     herskende klasse
# 9                            Nymarxist i norsk andedam
# 10                 Utopisk og vitenskapelig sosialisme
# 11                                     Svar på tiltale
# 12   Det revolusjonære spørsmål : føderalisme, sosi...
# 13                          Norsk sosialisme - hva nå?
# 14      Sosialismens utvikling fra utopi til vitenskap
# 15                                    Utopi og økonomi
# 16                                           Kapitalen
# 17                          Les til sommerleirene 1978
# 18                          Det kommunistiske manifest
# 19          Marx og Engels (ikke bare) for nybegynnere
# 20           Krisen i den borgerlige politiske økonomi
# 21                          Kultur og kulturrevolusjon
# 22                                  Inn i en ny verden
# 23                              Hva vil syndikalismen?
# 24                              Det beste av Karl Marx
# 25                               Hva Lenin egentlig sa
# 26                                Hva Marx egentlig sa
# 27                                       Lenin om Marx
# 28                               Sosialisme i Tanzania
# 29                                   Alt for mennesket
# ..                                                 ...
# 149                                Om å lese Kapitalen
# 150                          Sosialiserings-spørsmålet
# 151                       Kokkepiken og menneskeeteren
# 152    Imperialismen som kapitalismens høyeste stadium
# 153                                           AKP(m-l)
# 154                       Historie og klassebevissthet
# 155                                     Om motsigelsen
# 156                          Mennesket uten alternativ
# 157    Imperialismen som kapitalismens høyeste stadium
# 158                         Det kommunistiske manifest
# 159                         Brev og samtaler 1972-1975
# 160                  Slik arbeider marxist-leninistene
# 161                              Spørsmål i leninismen
# 162            Leve det proletariske diktaturets seier
# 163                                    Klassesamfunnet
# 164  Marxismen og det nasjonale og koloniale spørsm...
# 165                                          Opprørere
# 166                                          Kapitalen
# 167                                   herskende klasse
# 168                 Reis kampen blant arbeiderkvinnene
# 169                           Farvel til proletariatet
# 170                                Sosialimperialismen
# 171                             Kristendom og marxisme
# 172                      Du skal ta ledelsen og makten
# 173            Loven om profittratens fallende tendens
# 174                                       Om utbytting
# 175  historiske materialismen og dens historiske be...
# 176                                    Steinenes glede
# 177                Berlin-konferansen og våre oppgaver
# 178           "Radikalismen", kommunismens barnesykdom
#
#                                              subtittel  \
# 0
# 1
# 2
# 3                          grunntrekk og grunnbegreper
# 4    en undersøkelse av noen sider ved den stalinis...
# 5                       et handlingsprogram til debatt
# 6
# 7
# 8    en studie i klassemaktens historie og kapitali...
# 9
# 10                                   artikler og taler
# 11                                forsvar av marxismen
# 12
# 13
# 14
# 15
# 16                  kritikk av den politiske økonomien
# 17
# 18
# 19
# 20
# 21
# 22
# 23
# 24                                    tekster i utvalg
# 25
# 26
# 27
# 28                                   artiklar og talar
# 29
# ..                                                 ...
# 149                      en veiledning til Kapitalen I
# 150  et program til debatt : forsøk på ny analyse a...
# 151  et essay om forholdet mellom staten, marxismen...
# 152                    en allmennfattelig framstilling
# 153                              fare for demokratiet?
# 154                    studier i marxistisk dialektikk
# 155
# 156          om det mulige og umulige i å være marxist
# 157                    en allmennfattelig framstilling
# 158
# 159
# 160
# 161
# 162  Til minne om Pariserkommunens hundreårsdag &lt...
# 163
# 164                artiklar og talar i utval 1913-1934
# 165     profiler og skjebner fra sosialismens historie
# 166                 kritikk av den politiske økonomien
# 167  en studie i klassemaktens historie og kapitali...
# 168        studiebok om kvinnefrigjøring og sosialisme
# 169
# 170  Sovjet i dag : vedtak fra AKP (m-l)s landskonf...
# 171  en konfrontasjon mellom kristent og marxistisk...
# 172                    om å bygge sosialismen i Norden
# 173
# 174
# 175
# 176                           tilbakeblikk i dagsedler
# 177                                        [temahefte]
# 178
#
#                                                 forlag     sjanger  \
# 0                                              Oktober  notfiction
# 1                                               Ny dag  notfiction
# 2                                                Tiden  notfiction
# 3                                               Ny dag  notfiction
# 4                           Telemark distriktshøgskole  notfiction
# 5                                                  Pax  notfiction
# 6                                            Aschehoug  notfiction
# 7                                   Popular Book Depot
# 8                      Ny dag;Oslo : Ny dag, 1976-1977     unknown
# 9                                               Ny Dag  notfiction
# 10                                              Ny dag  notfiction
# 11                                             Oktober  notfiction
# 12                                   Abrakadabra forl.  notfiction
# 13                                            Cappelen  notfiction
# 14                                              Ny dag  notfiction
# 15                                             Ariadne  notfiction
# 16                        Oktober;Oslo : Oktober, 1983     unknown
# 17                                             Oktober  notfiction
# 18                                        Falken forl.  notfiction
# 19                                                 Pax  notfiction
# 20                                              Ny dag  notfiction
# 21                                              Ny dag  notfiction
# 22                          Arbeidernes ungdomsfylking  notfiction
# 23                                   Arbeiderns forlag  notfiction
# 24                                                 Pax  notfiction
# 25                                           Gyldendal  notfiction
# 26                                           Gyldendal  notfiction
# 27                                              Ny dag  notfiction
# 28                                 Det Norske Samlaget  notfiction
# 29                                   Alt for mennesket  notfiction
# ..                                                 ...         ...
# 149                                            Oktober  notfiction
# 150                                                     notfiction
# 151                                          Gyldendal  notfiction
# 152                                             Ny dag  notfiction
# 153                                                 Nå  notfiction
# 154                                          Gyldendal     unknown
# 155                                            Oktober  notfiction
# 156                                          Gyldendal  notfiction
# 157                                       Falken forl.  notfiction
# 158                                             Ny Dag  notfiction
# 159                                              Tiden  notfiction
# 160                                          Elingaard  notfiction
# 161                                            Oktober  notfiction
# 162                                                     notfiction
# 163                                       Falken forl.  notfiction
# 164                                            Oktober  notfiction
# 165                                              Tiden  notfiction
# 166                       Oktober;Oslo : Oktober, 1995  notfiction
# 167                    Ny dag;Oslo : Ny dag, 1976-1977     unknown
# 168                                            Oktober  notfiction
# 169                                                Pax  notfiction
# 170                                            Oktober  notfiction
# 171                                       Credo/Luther  notfiction
# 172                                                Pax  notfiction
# 173  Institutt for økonomi og Institutt for sosiolo...  notfiction
# 174                                                Pax  notfiction
# 175                                          Gyldendal  notfiction
# 176                                             Dreyer  notfiction
# 177                       NKP : i kommisjon hos Ny dag  notfiction
# 178                                             Ny Dag  notfiction
#
#                               sesamid språk       9
# 0    9a539f7c43feb2608bd08ee7bb861681   nob
# 1    99e721ab07d7ddb3bf52ba539099f884   nob     rus
# 2    39165716f4545230f8f3a4a22cf2f8cc   nob
# 3    4ed7f6d1c5983cce53f993411791e890   nob     ger
# 4    7754dc81e69ca6da676f7556b8eae979   nob
# 5    6306ed601f966c85c16fc23d96997ab3   nob
# 6    9d8657176c54f407534fcacc1d209de5   nob     eng
# 7    d7f15284cd6105e4e62e160967ce3908   mul
# 8    168ced99ca8a7f0eadb6b4f0a0dda998   nob
# 9    e0849cc0bbbe96a33f319e02916f0b93   nob
# 10   9ef7343d54172dc5c588781dbbb72480   nob     rus
# 11   5e30489fad3578fc696fd0a448bc48c6   nob
# 12   38e16e7d7ed9596292ad0b7383ab5453   nob     fre
# 13   9853413403ee3ebe5ef32daf21108784   nob
# 14   6fc2f5ace816890ac18657ae3196dac7   nob     ger
# 15   d3f26a0518886c9706d5037989c7681d   mul
# 16   7c270d63d3b8e10cf272f6e8d769e5d1   nob
# 17   d066fe7add566c5565f477a79e999d2f   nob
# 18   7132efde6728a10918c3a4f153cd72f3   nob     ger
# 19   3d13014861b82fb0d9dc5a19a656534d   nob     rus
# 20   184ab48ed090005165618d4ec0a813fe   nob     rus
# 21   021c260e682ddbcbf38d5eab563c641e   nob
# 22   0afdaca6986b4eb0040d86670b0ce28a   nob
# 23   7a352576410ba9d013d48fbab85788ce   mul
# 24   4b4d2d8502068355b6c6d8cdc1f3a587   nob     ger
# 25   e62d39158e819cf293aff422dc4ceab0   nob     ger
# 26   fd97cace3a7d8505f74b8694f35c77cf   nob     ger
# 27   14fbb8453e9bb34ce2411c741abe00bb   nob
# 28   3c5d942d895914a07e2313bcd1c52c37   nno     eng
# 29   43490db38f66e6b341009ce126aba82a   nob
# ..                                ...   ...     ...
# 149  65c017dba1612d5111b380cd7ccfecf9   nob
# 150  b4af713879e8817a5bcc509a2b52daab   nob
# 151  d6aba13fb965b16817263848487ffeaf   nob     fre
# 152  122ff9a42d82e6bc1667593c68c19164   nob     rus
# 153  c282ab60906690a4310a14453184deb9   nob
# 154  942501b0b2633be4bb1d2e8f98f85638   nob
# 155  67f263e8ef6049d8966b893e4d50b325   nob  engchi
# 156  a4ca1ff3f31fb05044ed2381d35dd10c   nob     pol
# 157  3ac3cd36deaabecb1d16acdbda79d8f2   nob     rus
# 158  2ad6d6292659637ea718c24278924f58   nob     ger
# 159  abe9ce5a076c4330da07a7844e44b344   nob     ger
# 160  03f6d8dd506fa402b6cc712d03ad830d   nob
# 161  77b940bae9642efeffb3de7ce979a3f5   nob     rus
# 162  e75e0c051bb9918aa5b8054443546fa3   nob
# 163  1ad72a7abdb0e5d58f190fc033fa8ab2   nob
# 164  c9950e3dae8c1c7bf137a0cd56aa2985   mul     rus
# 165  408f6816ab5fe93e97b1d2ec0821c9b8   nob
# 166  652b20a0b898848b1b8af4d3fc31245f   nob
# 167  83408c696dd24efe12c81f27b92f6c48   nob
# 168  094d64b11bc24ddf7ee89310455d9934   nob
# 169  56450341019cd24498a55b4677ab83c4   nob     fre
# 170  a0dc83d454be489d8c21c7b7c115111e   nob
# 171  65c244b7337511520771d06ef494fe7c   nob
# 172  20ba37733e30956d194aa80a22c0fe17   nob     swe
# 173  ffb4d6bfdd6324e537110b9681e55817   nob
# 174  3264ab17226afc44204069ed60abb554   nob
# 175  9b68a06c83fc38ca406c388e67bde174   nob
# 176  bba2eaaf0f11ed129b89f99b52b08c11   nob     fre
# 177  8b1db11f385153d862a8aeffb61f3e48   nob
# 178  11bb6fca6e4bc65467a63fb881d3bc88   nob
#
# [179 rows x 10 columns]

# %% [markdown]
# ### Søk etter sett av ord i clustret

# %%
nb.frame_sort(bøker_typiske_ord.loc['det sår krig . , gevær våpen generaler soldater blod fattigdom nød'.split()])
# Out:
#               ratio
# fattigdom  0.002115
# krig       0.002077
# generaler  0.001446
# våpen      0.001436
# nød        0.001154
# det        0.000651
# soldater   0.000505
# ,          0.000439
# .          0.000341
# blod       0.000304
# gevær      0.000206
# sår        0.000151

# %%
G = nb.make_network(2007060501049,"""revolusjonen, kritikk, arbeiderklassen, virkelige, sosialistiske, revolusjon, samfunnets, herredømme, sosialisme, samfunnet, samfunn, borgerskapet, proletariatet, samfunnsmessige, teorien, herskende, kapitalen, sosialismen, materielle, demokratiske, allmenne, kapitalistiske, arbeiderne, arbeidernes, proletariatets, vesentlige, eksistens, samfunnsmessig, borgerlige, arbeiderklassens, arbeidskraft, naturen, arbeidende, revolusjonær, Frankrike, menneskets, kommunismen, menneskelig, utbytting, økonomien, klassekampen, middel, revolusjonære, nødvendighet, arbeideren, skiller, vitenskap, grunnleggende, vitenskapelig, intellektuelle, uunngåelig, produksjonsmidlene, frie, prinsipp, nasjoner, massene, absolutte, kjempe, opprør, umiddelbart, kamp, enhet, undertrykte, 1848, vitenskapen, bind, kapitalistene, allmenn, bønder, frigjøring, vitenskapelige, Paris, virkelighet, diktatur, følgelig, klassene, sosialistisk, produksjon, Marx, politikken, arbeidere, motsetningen, Kapitalen, umiddelbare, produksjonsforhold, menneskenes, produserer, Hegel, produsere, konkurransen, borgerskapets, bevissthet, grunnlaget, eiendom, frihet, kapitalister, kapitalist, slutter, religiøse, produktive, innbyrdes, tvinger, forsvinner, folkets, forvandlet, profitt, kapitalisten, organer, sosial, produksjonen, borgerskap, trinn, nasjon, massen, filosofiske, Kapitalens, arbeidets, sosialt, produktene, nødvendigheten, profitten, avskaffe, kritikken, egenskap, klassekamp, hersker, produksjonsmidler, proletariske, produktet, Lenins, proletariat, skaper, kapitalismen, fellesskap, partiet, objektive, kommunisme, lykkes, eksistere, storindustrien, kommunistene, produksjonsprosessen, slaver, bekostning, flertallet, Italia, vold, abstrakt, demokratisk, individ""".split(', '))

# %%
nb.central_betweenness_characters(G)
# Out:
# [('demokratiske', 0.21176671125644594),
#  ('samfunn', 0.1961271006551108),
#  ('kamp', 0.1608712077657222),
#  ('partiet', 0.10043776319351767),
#  ('demokratisk', 0.08667803063707484),
#  ('revolusjonær', 0.0731846452615384),
#  ('sosialisme', 0.07280438029485532),
#  ('samfunnsmessig', 0.0700359725858359),
#  ('revolusjonære', 0.0674184995601653),
#  ('diktatur', 0.05641945501763369)]

# %%
gnl.show_graph(G, spread = 0.5, fontsize=12)
# Out:
# D:\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
bok = nb.pure_urn(bøker)[10]
nb.metadata(bok)
# Out:
# [[2012010508040,
#   'Lenin, V.I.',
#   1970,
#   'Utopisk og vitenskapelig sosialisme',
#   'artikler og taler',
#   'Ny dag',
#   'notfiction',
#   '9ef7343d54172dc5c588781dbbb72480',
#   'nob',
#   'rus']]

# %%
R = nb.navn(bok)
R
# Out:
# {'Adam': 3,
#  'Al': 2,
#  'Aleksander': 2,
#  'Alexander': 3,
#  'Amerika': 4,
#  'Anti-Diihring': 3,
#  'Anti-Duhring': 2,
#  'Antonii': 3,
#  'Arbeiderpartiets': 2,
#  'Arbeidets': 2,
#  'Artikkelen': 3,
#  'Asia': 7,
#  'Asias': 2,
#  'Avskaffelse': 2,
#  'Bakunin': 4,
#  'Barmen': 6,
#  'Bauer': 5,
#  'Bebel': 2,
#  'Belgia': 2,
#  'Berlin': 2,
#  'Bernstein': 6,
#  'Bernsteins': 4,
#  'Besdna': 3,
#  'Bismarck': 7,
#  'Bismarcks': 2,
#  'Blanc': 2,
#  'Bondekongressen': 3,
#  'Bondens': 2,
#  'Bondespørsmålet': 3,
#  'Bonn': 4,
#  'Brev': 6,
#  'Brevvekslingen': 4,
#  'Briefwechsel': 13,
#  'Bruno': 3,
#  'Brussel': 2,
#  'Charter': 2,
#  'Dag': 2,
#  'Dagbladet': 2,
#  'Darwin': 2,
#  'David': 3,
#  'Demokrati': 2,
#  'Die': 4,
#  'Dietzgens': 2,
#  'Diihring': 4,
#  'Diihrings': 2,
#  'Drews': 2,
#  'Edvard': 2,
#  'Einstein': 3,
#  'Ekonomist': 2,
#  'Elberfeld': 3,
#  'Engels': 165,
#  'England': 13,
#  'Erfurtprogrammet': 2,
#  'Europa': 28,
#  'Europas': 2,
#  'Familiens': 2,
#  'Feuerbach': 11,
#  'Feuerbachs': 6,
#  'Filosofiens': 7,
#  'Folkets': 5,
#  'Folkevennene': 2,
#  'Forbund': 3,
#  'Forord': 2,
#  'Frankreich': 2,
#  'Frankrike': 17,
#  'Friedrich': 10,
#  'Friheten': 2,
#  'Fullstendig': 4,
#  'Første': 3,
#  'Geneve': 7,
#  'Gorki': 2,
#  'Grim': 2,
#  'Hegel': 9,
#  'Hegels': 15,
#  'Helt': 3,
#  'Herzen': 47,
#  'Herzens': 11,
#  'Imperialismen': 2,
#  'Innstikk': 2,
#  'Internasjonale': 3,
#  'Internasjonalen': 3,
#  'Internasjonalens': 4,
#  'Iskra': 2,
#  'Jahrbiicher': 2,
#  'Japan': 4,
#  'Jenny': 2,
#  'Kapitalen': 38,
#  'Kapitalismens': 3,
#  'Karl': 11,
#  'Kavelin': 3,
#  'Kina': 20,
#  'Kinas': 3,
#  'Klassekampene': 2,
#  'Koln': 5,
#  'Kolokol': 10,
#  'Kommunen': 3,
#  'Kommunistenes': 4,
#  'Kommunistiske': 3,
#  'Kostrov': 3,
#  'Kristendommens': 2,
#  'Kritikk': 3,
#  'Kugelmann': 11,
#  'Kulturkampf': 2,
#  'Larm': 4,
#  'Lassalle': 3,
#  'Lassalles': 2,
#  'Lenin': 28,
#  'Lenins': 6,
#  'Liebknecht': 2,
#  'Literarischer': 2,
#  'London': 18,
#  'Louis': 4,
#  'Ludwig': 5,
#  'Lunatsjarski': 2,
#  'Majesteten': 2,
#  'Manchester': 4,
#  'Manilov': 2,
#  'Marx': 328,
#  'Marxismens': 4,
#  'Merverdien': 2,
#  'Mikhailovski': 2,
#  'Moskovskije': 2,
#  'Moskva': 5,
#  'Munisipaliseringen': 2,
#  'Mysl': 5,
#  'Nachlass': 2,
#  'Narodnaja': 4,
#  'Nasjonalisering': 4,
#  'Neve': 7,
#  'Nikolai': 3,
#  'Noen': 5,
#  'Noter': 2,
#  'Ny': 3,
#  'Oslo': 2,
#  'Paris': 17,
#  'Pariskommunen': 3,
#  'Polen': 5,
#  'Polens': 2,
#  'Poljarnaja': 3,
#  'Pravda': 7,
#  'Pravdy': 3,
#  'Proletarij': 7,
#  'Proudhon': 8,
#  'Proudhons': 4,
#  'Przedswit': 2,
#  'Purisjkevitsj': 4,
#  'Put': 3,
#  'RSDAPs': 5,
#  'Rakitnikovs': 2,
#  'Revolutsionnaja': 6,
#  'Rheinische': 5,
#  'Ricardos': 2,
#  'Rodbertus': 2,
#  'Rossija': 6,
#  'Ruge': 3,
#  'Russkoje': 2,
#  'Russland': 114,
#  'Russland.': 2,
#  'Russlands': 12,
#  'Samme': 2,
#  'Se': 12,
#  'Shanghai': 2,
#  'Shih-kai': 3,
#  'Sibir': 2,
#  'Sjisn': 2,
#  'Smith': 2,
#  'Sorge': 4,
#  'Sosialdemokratiets': 3,
#  'St': 2,
#  'Stockholm': 2,
#  'Stoikaja': 2,
#  'Sun': 14,
#  'Surkov': 2,
#  'Surkovs': 3,
#  'Sveits': 2,
#  'Svesda': 2,
#  'Tale': 4,
#  'Teorier': 2,
#  'To': 4,
#  'Trier': 2,
#  'Tsjernysjevskij': 5,
#  'Turgenjev': 3,
#  'Tyskland': 28,
#  'Ukraina': 2,
#  'Undertegnet': 2,
#  'Utdrag': 10,
#  'Utopisk': 7,
#  'Vedomosti': 2,
#  'Vekhi': 2,
#  'Venstrenarodnisme': 2,
#  'Versailles': 3,
#  'Vest': 3,
#  'Vest-': 2,
#  'Vest-Europa': 2,
#  'Vesten': 9,
#  'Vestens': 2,
#  'Vogt': 2,
#  'Våre': 3,
#  'Vårt': 2,
#  'Yat-sen': 9,
#  'Yat-sens': 5,
#  'Zeit': 4,
#  'Zeitung': 6,
#  'Østen': 4,
#  'Østerrike': 2}

# %%
RN = nb.check_navn(R, limit=2)

# %%
RN
# Out:
# {'Adam': 3,
#  'Alexander': 3,
#  'Amerika': 4,
#  'Anti-Diihring': 3,
#  'Antonii': 3,
#  'Artikkelen': 3,
#  'Asia': 7,
#  'Bakunin': 4,
#  'Barmen': 6,
#  'Bauer': 5,
#  'Bernstein': 6,
#  'Bernsteins': 4,
#  'Besdna': 3,
#  'Bismarck': 7,
#  'Bondekongressen': 3,
#  'Bondespørsmålet': 3,
#  'Bonn': 4,
#  'Brev': 6,
#  'Brevvekslingen': 4,
#  'Briefwechsel': 13,
#  'Bruno': 3,
#  'David': 3,
#  'Die': 4,
#  'Diihring': 4,
#  'Einstein': 3,
#  'Elberfeld': 3,
#  'Engels': 165,
#  'England': 13,
#  'Europa': 28,
#  'Feuerbach': 11,
#  'Feuerbachs': 6,
#  'Filosofiens': 7,
#  'Folkets': 5,
#  'Forbund': 3,
#  'Frankrike': 17,
#  'Friedrich': 10,
#  'Fullstendig': 4,
#  'Første': 3,
#  'Geneve': 7,
#  'Hegel': 9,
#  'Hegels': 15,
#  'Helt': 3,
#  'Herzen': 47,
#  'Herzens': 11,
#  'Internasjonale': 3,
#  'Internasjonalen': 3,
#  'Internasjonalens': 4,
#  'Japan': 4,
#  'Kapitalen': 38,
#  'Kapitalismens': 3,
#  'Karl': 11,
#  'Kavelin': 3,
#  'Kina': 20,
#  'Kinas': 3,
#  'Koln': 5,
#  'Kolokol': 10,
#  'Kommunen': 3,
#  'Kommunistenes': 4,
#  'Kommunistiske': 3,
#  'Kostrov': 3,
#  'Kritikk': 3,
#  'Kugelmann': 11,
#  'Larm': 4,
#  'Lassalle': 3,
#  'Lenin': 28,
#  'Lenins': 6,
#  'London': 18,
#  'Louis': 4,
#  'Ludwig': 5,
#  'Manchester': 4,
#  'Marx': 328,
#  'Marxismens': 4,
#  'Moskva': 5,
#  'Mysl': 5,
#  'Narodnaja': 4,
#  'Nasjonalisering': 4,
#  'Neve': 7,
#  'Nikolai': 3,
#  'Noen': 5,
#  'Ny': 3,
#  'Paris': 17,
#  'Pariskommunen': 3,
#  'Polen': 5,
#  'Poljarnaja': 3,
#  'Pravda': 7,
#  'Pravdy': 3,
#  'Proletarij': 7,
#  'Proudhon': 8,
#  'Proudhons': 4,
#  'Purisjkevitsj': 4,
#  'Put': 3,
#  'RSDAPs': 5,
#  'Revolutsionnaja': 6,
#  'Rheinische': 5,
#  'Rossija': 6,
#  'Ruge': 3,
#  'Russland': 114,
#  'Russlands': 12,
#  'Se': 12,
#  'Shih-kai': 3,
#  'Sorge': 4,
#  'Sosialdemokratiets': 3,
#  'Sun': 14,
#  'Surkovs': 3,
#  'Tale': 4,
#  'To': 4,
#  'Tsjernysjevskij': 5,
#  'Turgenjev': 3,
#  'Tyskland': 28,
#  'Utdrag': 10,
#  'Utopisk': 7,
#  'Versailles': 3,
#  'Vest': 3,
#  'Vesten': 9,
#  'Våre': 3,
#  'Yat-sen': 9,
#  'Yat-sens': 5,
#  'Zeit': 4,
#  'Zeitung': 6,
#  'Østen': 4}

# %%
GR = nb.make_network_graph(bok, RN)

# %%
gnl.show_graph(GR,  spread = 1.2, fontsize=12)
# Out:
# D:\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
nb.central_betweenness_characters(GR, 20)
# Out:
# [('Marx', 0.3133750641220449),
#  ('Russland', 0.21379882438604308),
#  ('Engels', 0.13429491853983244),
#  ('Herzen', 0.08955972715342143),
#  ('Lenin', 0.08420084441567699),
#  ('London', 0.07035032664584001),
#  ('Europa', 0.06471400017494065),
#  ('Tyskland', 0.051225166111522925),
#  ('Russlands', 0.037418036460398756),
#  ('England', 0.029836125971063374),
#  ('Sun', 0.02456524227842139),
#  ('Frankrike', 0.024447993684797286),
#  ('Ny', 0.023501822374501415),
#  ('Yat-sen', 0.021551391781248482),
#  ('Geneve', 0.01798247980600808),
#  ('Bondekongressen', 0.017631092394446005),
#  ('Utdrag', 0.01748452696728559),
#  ('Nikolai', 0.017094017094017096),
#  ('Moskva', 0.017094017094017096),
#  ('Besdna', 0.017094017094017092)]

# %%
nb.central_characters(GR, 20)
# Out:
# [('Marx', 0.6068376068376069),
#  ('Engels', 0.4786324786324787),
#  ('Russland', 0.3760683760683761),
#  ('Tyskland', 0.2991452991452992),
#  ('London', 0.2905982905982906),
#  ('Paris', 0.2136752136752137),
#  ('Herzen', 0.20512820512820515),
#  ('Europa', 0.1965811965811966),
#  ('Frankrike', 0.17948717948717952),
#  ('Feuerbach', 0.1623931623931624),
#  ('England', 0.15384615384615385),
#  ('Lenin', 0.1452991452991453),
#  ('Hegels', 0.13675213675213677),
#  ('Karl', 0.13675213675213677),
#  ('Die', 0.13675213675213677),
#  ('Neve', 0.13675213675213677),
#  ('Geneve', 0.12820512820512822),
#  ('Ludwig', 0.12820512820512822),
#  ('Bauer', 0.11965811965811968),
#  ('Russlands', 0.11965811965811968)]
