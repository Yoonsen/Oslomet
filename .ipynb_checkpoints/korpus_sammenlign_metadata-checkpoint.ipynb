# %% [markdown]
# # Undersøk korpus med metadata
#
# Notebook for å undersøke korpus med metadata

# %%
import requests

# hent Python-modulen nbtext.py fra Github
nba = requests.get("https://raw.githubusercontent.com/Yoonsen/Modules/master/nbtext.py").text
with open('nbtext.py','w', encoding='UTF-8') as pyfile:
    pyfile.write(nba)

# hent nbpictures.py fra Github
nbb = requests.get("https://raw.githubusercontent.com/Yoonsen/Modules/master/nbpictures.py").text
with open('nbpictures.py','w', encoding='UTF-8') as pyfile:
    pyfile.write(nbb)

import nbtext as nb
import nbpictures as pct

from nbtext import Corpus

# %% [markdown]
# Kommandoen for å lage et korpus er *Corpus()* som bygger et korpus av tekster som sammenlignes med en referanse. I det her eksemplet bygges referansen samtidig, men i et ideelt tilfelle kan vi ønske å la referansen være ferdigbygd et sted.

# %%
objekt = Corpus(
    period=(1950, 2010),
    #title='%',
    #subject='krig',
    ddk='335%',
    reference=50,
    max_books=50)

# %% [markdown]
# ## Undersøk forskjeller
#
# Dataene viser forskjellem mellom målkorpus og referanse. Se på differansen med kommandoen *difference* som tar et sett parametre. De viktigste for analysen er *freq_exp* som vekter frekvensen til ordene i målkorpuset, og *doc_exp* som vekter dokumentfrekvensen i målkorpuset.
#
# Settes verdien for *top* lik null får du hele korpuset.

# %%
objekt.difference(top=10, aslist=False, freq_exp=1.1, doc_exp=1.5)
# Out:
#                     diff
# samfunn         0.033100
# Marx            0.032491
# samfunnet       0.032349
# politiske       0.031573
# kapitalistiske  0.030653
# revolusjon      0.029952
# sosialistiske   0.029522
# kamp            0.029333
# borgerlige      0.028809
# politisk        0.027500

# %%
objekt.difference(top=150)
# Out:
# Marx, samfunn, samfunnet, kapitalistiske, revolusjon, sosialistiske, borgerlige, revolusjonære, arbeiderne, politiske, arbeiderklassen, revolusjonen, sosialismen, samfunnsmessige, kapitalen, kamp, borgerskapet, proletariatet, kritikk, materielle, virkelige, produksjonen, sosialisme, Lenin, kapital, arbeidere, partiet, kapitalismen, kommunistiske, Engels, MEW, proletariatets, Frankrike, samfunnets, dens, arbeideren, frihet, arbeidskraft, allmenne, herskende, produksjon, historiske, naturen, samfunnsmessig, sosialistisk, herredømme, parti, massene, demokratiske, kampen, revolusjonær, politisk, grunnleggende, arbeidende, arbeiderklassens, intellektuelle, menneskets, marxismen, eiendom, eksistens, arbeidernes, økonomiske, teorien, kommunismen, frie, enhet, diktatur, dets, Lenins, interesser, menneskelige, marxistiske, skaper, makt, bevissthet, politikken, virkeligheten, økonomien, mennesket, menneskelig, produksjonsmidlene, utbytting, grunnlaget, Paris, tyske, bind, sosial, krisa, partiene, franske, folket, produserer, kapitalisten, objektive, vesentlige, merverdien, russiske, kapitalens, absolutte, vitenskap, makten, klassekampen, politikk, Kapitalen, sosialdemokratiske, moderne, produsere, borgerskapets, umiddelbart, middel, natur, merverdi, pund, 1848, virkelighet, eksisterer, proletariske, vare, kommunistene, arbeidets, produktet, skiller, sosiale, produksjonsmidler, nødvendighet, profitt, motsetning, demokrati, produksjonsforhold, kjempe, vitenskapelig, undertrykte, folkets, klasser, enhver, menneskenes, kapitalistene, skapt, uunngåelig, religiøse, utviklet, 808, utviklingen, imperialistiske, bevegelse, konkurransen, Russland, varene, bønder, vitenskapen

# %% [markdown]
# Legg til summary() for se litt hva korpuset inneholder

# %%
objekt.summary()
# Out:
# {'parameters': {'author': '%',
#   'ddk': '335%',
#   'limit': 50,
#   'next': 60,
#   'reference': 50,
#   'subject': '%',
#   'title': '%',
#   'year': 1950},
#  'reference urn': [2013091706149,
#   2011041308056,
#   2011050208042,
#   2011120108072,
#   2013031106000,
#   2009032004032,
#   2009062301044,
#   2008111304004,
#   2009070900078,
#   2009021004067],
#  'target_urn': [2013040307023,
#   2007092401072,
#   2008052804073,
#   2007073001121,
#   2010082403018,
#   2007060501049,
#   2016082408022,
#   2007072300076,
#   2014050706057,
#   2013102906141]}

# %% [markdown]
# # Metadata for korpuset kan raskt sjekkes
#
# Pass på at ikke korpuset er for stort (mange tusen).

# %%
nb.metadata(objekt.target_urn)
# Out:
# [[2013040307023,
#   'Rius',
#   1981,
#   'Marx for begynnere',
#   'Gyldendal',
#   'nob',
#   'spa'],
#  [2007092401072,
#   'Nilsen, Fritz',
#   1991,
#   'Norsk sosialisme - hva nå?',
#   'Cappelen',
#   'nob',
#   ''],
#  [2008052804073,
#   'Berntsen, Harald',
#   1976,
#   'historiske materialismen og dens historiske betingelser',
#   'Gyldendal',
#   'nob',
#   ''],
#  [2007073001121,
#   'Enerstvedt, Regi Th.',
#   1969,
#   'Dialektikk og samfunnsvitenskap',
#   'Ny dag',
#   'nob',
#   ''],
#  [2010082403018,
#   'Marx, Karl',
#   1998,
#   'Det kommunistiske manifest',
#   'Røde fane',
#   'nob',
#   'ger'],
#  [2007060501049,
#   'Brandt, Willy',
#   1976,
#   'Brev og samtaler 1972-1975',
#   'Tiden',
#   'nob',
#   'ger'],
#  [2016082408022,
#   'Bakunin, Michail',
#   2002,
#   'Det revolusjonære spørsmål : føderalisme, sosialisme og antiteologi ; Pariserkommunen : en dristig negasjon av staten',
#   'Abrakadabra forl.',
#   'nob',
#   'fre'],
#  [2007072300076, '', 1975, 'Sosialimperialismen', 'Oktober', 'nob', ''],
#  [2014050706057,
#   'Lévy, Bernard-Henri',
#   1979,
#   'Barbari med menneskelig ansikt',
#   'Aschehoug',
#   'nob',
#   'fre'],
#  [2013102906141, 'Guérin, Daniel', 1969, 'Anarkismen', 'Pax', 'nob', 'fre'],
#  [2012011708001,
#   'Dimitrov, Georgij',
#   1972,
#   'Enhet mot fascisme og krig',
#   'Ny dag',
#   'nob',
#   ''],
#  [2014031406074,
#   'Elster, Jon',
#   1988,
#   'Hva er igjen av Marx?',
#   'Universitetsforlaget',
#   'nob',
#   'eng'],
#  [2012022008185,
#   'Deutscher, Isaac',
#   1972,
#   'Lenins barndom ; Marxisme i vår tid',
#   'Aschehoug',
#   'nob',
#   'eng'],
#  [2007052401016, 'Gjessing, Gutorm', 1967, 'Kibbutz', 'Pax', 'nob', ''],
#  [2015050748010,
#   'Marx, Karl',
#   2005,
#   'Kapitalen',
#   'Forlaget Oktober',
#   'nob',
#   'ger'],
#  [2012021608159,
#   'Marcuse, Herbert',
#   1972,
#   'Sovjet-marxismen',
#   'Pax',
#   'nob',
#   'eng'],
#  [2012041308235, '', 1973, 'Marx i dag', 'Gyldendal', 'nob', ''],
#  [2015073008011,
#   '',
#   2010,
#   'Marx-Engels-leksikon',
#   'Marxist forl.',
#   'nob',
#   'ger'],
#  [2012100108077, 'Barradas, Carlos', 2009, 'Karl Marx', 'Rødt!', 'nob', ''],
#  [2010100608047,
#   'Marx, Karl',
#   1995,
#   'Kapitalen',
#   'Oktober;Oslo : Oktober, 1995',
#   'nob',
#   ''],
#  [2007053101001,
#   'Pannekoek, Anton',
#   1975,
#   'Parti, råd, revolusjon',
#   'Pax',
#   'nob',
#   'ger'],
#  [2014070307015,
#   'Nyerere, Julius K.',
#   1976,
#   'Fattigdom og frigjering',
#   'Samlaget',
#   'mul',
#   'eng'],
#  [2012080308070,
#   'Marx, Karl',
#   2000,
#   'Det kommunistiske manifest og andre ungdomsskrifter',
#   'De norske bokklubbene',
#   'nob',
#   'ger'],
#  [2012050808066,
#   '',
#   1973,
#   'Sosialismen og Europa i 70-åra',
#   'Tiden',
#   'nob',
#   ''],
#  [2007081700019,
#   'Jagland, Thorbjørn',
#   1990,
#   'Min europeiske drøm',
#   'Tiden',
#   'nob',
#   ''],
#  [2010100608046,
#   'Marx, Karl',
#   1995,
#   'Kapitalen',
#   'Oktober;Oslo : Oktober, 1995',
#   'nob',
#   ''],
#  [2015021308033,
#   '',
#   1976,
#   'Leninismens plass i marxismen',
#   'Forbundet',
#   'nob',
#   ''],
#  [2015021006004,
#   'Mao, Zedong',
#   1967,
#   'Sitater fra formann Mao-Tse-Tung',
#   'Forl. for fremmede språk',
#   'nob',
#   'chi'],
#  [2008052304014,
#   'Mandel, Ernest',
#   1975,
#   'Seinkapitalismen',
#   'Gyldendal',
#   'nob',
#   'ger'],
#  [2007070300039, 'Brøgger, Jan', 1978, 'Marxismen', 'Nå forlag', 'nob', ''],
#  [2013041807152,
#   '',
#   1978,
#   'Marxisme og kvinnefrigjering',
#   'Oktober',
#   'nno',
#   ''],
#  [2016081708053, '', 1978, 'Kristne i kamp for sosialismen', 'FKS', 'nob', ''],
#  [2007052100009,
#   'Gorz, André',
#   1967,
#   'Nykapitalismen og arbeiderklassen',
#   'Tiden',
#   'nob',
#   'fre'],
#  [2007071900090,
#   'Fischer, Ernst',
#   1971,
#   'Hva Lenin egentlig sa',
#   'Gyldendal',
#   'nob',
#   'ger'],
#  [2007102400056,
#   'Marx, Karl',
#   1992,
#   'Karl Marx : arbeid, kapital, fremmedgjøring',
#   'Falken',
#   'nob',
#   'ger'],
#  [2007053001006,
#   'Christophersen, Jens A.',
#   1968,
#   'Verdensrevolusjonen som ble vekk',
#   'Pax',
#   'nob',
#   ''],
#  [2012110108069,
#   'Marx, Karl',
#   1983,
#   'Kapitalen',
#   'Oktober;Oslo : Oktober, 1983',
#   'nob',
#   ''],
#  [2007082201013,
#   'Wilde, Oscar',
#   1991,
#   'Sosialismen og menneskets sjel',
#   'Solum',
#   'nob',
#   'eng'],
#  [2010081608018,
#   'Kleven, Hans I.',
#   1998,
#   'Klassesamfunnet',
#   'Falken forl.',
#   'nob',
#   ''],
#  [2007112601070,
#   'Marx, Karl',
#   1992,
#   'Det beste av Karl Marx',
#   'Pax',
#   'nob',
#   'ger'],
#  [2013120605009,
#   'Ustvedt, Yngvar',
#   1977,
#   'De utopiske sosialister',
#   'Tiden;Emil Moestue',
#   'nob',
#   ''],
#  [2010070808023,
#   'Rius',
#   1995,
#   'Marx for begynnere',
#   'Bracan forl.',
#   'nob',
#   'engspa'],
#  [2014010708229,
#   'Tuastad, Svein',
#   2009,
#   'Fridom, likskap og gullkort',
#   'Samlaget',
#   'nno',
#   ''],
#  [2007072700015,
#   'Djilas, Milovan',
#   1969,
#   'Det ufullkomne samfunn',
#   'Gyldendal',
#   'nob',
#   'enghrv'],
#  [2007070500091,
#   'Kolakowski, Leszek',
#   1978,
#   'revolusjonære ånd',
#   'Dreyer',
#   'nob',
#   'ger'],
#  [2012031308152,
#   'Holm, Harald',
#   1973,
#   'Innføring i politisk økonomi',
#   'Ny dag',
#   'nob',
#   ''],
#  [2011062905181,
#   'Marx, Karl',
#   1964,
#   'Det kommunistiske manifest',
#   'Tiden',
#   'mul',
#   'ger'],
#  [2013032208014,
#   'Lenin, V.I.',
#   1970,
#   'Mot dogmatisme, sekterisme og "venstre"-opportunisme',
#   'Ny dag',
#   'nob',
#   'rus'],
#  [2013061108080,
#   'Lenin, V.I.',
#   1968,
#   'Staten og revolusjonen',
#   'Ny Dag',
#   'nob',
#   'rus'],
#  [2007061100051,
#   'Kolakowski, Leszek',
#   1966,
#   'Mennesket uten alternativ',
#   'Gyldendal',
#   'nob',
#   'pol']]

# %% [markdown]
# ### Søk etter sett av ord i clustret
#
# Finn verdien for ord i clusteret med objekt.check_words('o1 o2 o3 ... oN') med opsjonell spesifikasjon av eksponent. Bare list ordene opp med mellomrom, ord som ikke er i clusteret vil heller ikke vises. Alle andre vises med assosiasjonsverdien og sorteres var høy til lav. Tittel på kolonnen gir en påminnelse om ordet listen er kollokert fra.

# %%
objekt.search_words( 'sår krig . , gevær våpen generaler soldater blod fattigdom nød')
# Out:
#                diff
# krig       0.389897
# våpen      0.381583
# nød        0.354876
# fattigdom  0.314262
# ,          0.241312
# .          0.212405
# soldater   0.120081
# blod       0.017202

# %%
nb.cloud(objekt)
