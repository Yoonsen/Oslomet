# %% [markdown]
# # OsloMet - tema og innhold
#
# * Lars G. Johnsen
# * lars.johnsen@nb.no
# * Nasjonalbiblioteket

# %% [markdown]
# Importer ressurser

# %%
import dhlab.module_update as mu
import dhlab.nbtext as nb
import dhlab.nbpictures as pc
mu.update('mods_meta')
import mods_meta as mm
import pandas as pd
# Out:
# Updated file `C:\Users\yoons\Documents\GitHub\Oslomet\mods_meta.py`

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# Mer detaljert metadata

# %%
meta = mm.meta_natbib(children = False, yearfrom = 1990, yearto = 2000)
meta
# Out:
# [[999401144614702201, 2008082804065],
#  [999814287114702201, 2008071404024],
#  [999000928314702201, 2007092500029],
#  [999430610754702201, 2016110948089],
#  [999816032464702201, 2008091104038],
#  [999610644804702201, 2010072903013],
#  [999407294824702201, 2012101708094],
#  [999903940934702201, 2015052008090],
#  [999422053404702201, 2007121304045],
#  [999423079844702201, 2008062304005],
#  [999001691764702201, 2007110804049],
#  [999720972954702201, 2009042004094],
#  [999721548764702201, 2010041903056],
#  [999430698154702201, 2013121108221],
#  [999602738324702201, 2010071503020],
#  [999102174914702201, 2009051300061],
#  [999901755024702201, 2008101004024],
#  [999422259534702201, 2007121204092],
#  [990003428584702201, 2011030905027],
#  [999601839734702201, 2017062307066]]

# %%
urner = [x[1] for x in meta]
urner
# Out:
# [2008082804065,
#  2008071404024,
#  2007092500029,
#  2016110948089,
#  2008091104038,
#  2010072903013,
#  2012101708094,
#  2015052008090,
#  2007121304045,
#  2008062304005,
#  2007110804049,
#  2009042004094,
#  2010041903056,
#  2013121108221,
#  2010071503020,
#  2009051300061,
#  2008101004024,
#  2007121204092,
#  2011030905027,
#  2017062307066]

# %%
meta_df = nb.frame(mm.metadata(urner))
meta_df
# Out:
#                              100-1- -a  \
# 2007092500029    Lillemyr, Ole Fredrik
# 2007121204092            Borgen, Johan
# 2007121304045           Vachss, Andrew
# 2008062304005         Stordalen, Terje
# 2008071404024          Knudsen, Werner
# 2008082804065           Skahjem, Svein
# 2008091104038        Ekorness, Karsten
# 2008101004024          Førde, Per Inge
# 2009042004094  Torseter, Anne Margrete
# 2009051300061         Gordimer, Nadine
# 2010041903056          Rigault, Didier
# 2010071503020            Ross, Stewart
# 2010072903013            Grisham, John
# 2011030905027        Dragsnes, Hans L.
# 2012101708094        Schanche, Audhild
# 2013121108221           Pendleton, Don
# 2015052008090       Adriansen, Karsten
# 2016110948089          Guttu, Kristian
# 2017062307066          Båsland, Harald
# 2007110804049                      NaN
#
#                                                        245-1-0-a  \
# 2007092500029                                    Leik på alvor :
# 2007121204092                                    Vi har ham nå :
# 2007121304045                                             Strega
# 2008062304005                                 Støv og livspust :
# 2008071404024                                 Internett for alle
# 2008082804065                                   Rød skole 125-år
# 2008091104038                                   Hvor er de nå? :
# 2008101004024                                Kjærlighetens vei :
# 2009042004094                               Hva er det med Desi?
# 2009051300061                                 Min sønns historie
# 2010041903056                                    Importavtaler :
# 2010071503020                                          Sjørøvere
# 2010072903013                                           Klienten
# 2011030905027                               Leiarskap til sjøs :
# 2012101708094                       Ceavccageaðgi - Mortensnes :
rett, kontraktsutforming, norge, vilkår, sjørøveri, nan, fag, fiskerifag, lærebøker, nautiske, skole, videregående, arkeologi, boplasser, finnmark, fornminner, historie, kulturminner, lokalhistorie, nesseby, samer, tilrettelegging, nan, gjeldsforhandlinger, konkurs, konkursboer, konkurssaker, norge, skifterettsbehandling, nan, 5., 5klasse, 6-åringer, grunnskolen, klasse, lærebok, lærebøker, læremiddel, m87, norsk, norskfag, rettskriving, språk, bhagavadgita, filosofi, hinduisme, india, religion, østen'

# %%
meta_df['653- - -a'].apply(lambda x: str(x).split(',')).to_dict()
# Out:
# {'2007092500029': [':barnepsykologi',
#   ' barn',
#   ' barnehage',
#   ' barnehager',
#   ' barnelek',
#   ' barnepsykologi',
#   ' formallm',
#   ' førskolebarn',
#   ' førskolen',
#   ' førskolepedagogikk',
#   ' førskoler',
#   ' leik',
#   ' lek',
#   ' leketeori',
#   ' leketeorier',
#   ' lekteorier',
#   ' også',
#   ' pedagogikk',
#   ' pedagogisk',
#   ' psykologi',
#   ' se',
#   ' småbarnsalder'],
#  '2007121204092': ['nan'],
#  '2007121304045': ['nan'],
#  '2008062304005': ['antropologi',
#   ' bibelen',
#   ' bibelfortolkninger',
#   ' bibelteologi-gt',
#   ' gamle',
#   ' gt',
#   ' kristen',
#   ' mennesker',
#   ' menneskesyn',
#   ' mennesket',
#   ' testamente',
#   ' tro'],
#  '2008071404024': ['brukerveiledninger',
#   ' datanett',
#   ' hjemmesider',
#   ' internet',
#   ' internett',
#   ' nettverk',
#   ' søking',
#   ' www'],
#  '2008082804065': ['nan'],
#  '2008091104038': ['evangeliesenteret'],
#  '2008101004024': ['nan'],
#  '2009042004094': ['nan'],
#  '2009051300061': ['africana',
#   ' apartheid',
#   ' roman',
#   ' skjønnlitteratur/voksen',
#   ' sørafrika'],
#  '2010041903056': ['avtalerett',
#   ' handelsrett',
#   ' import',
#   ' importhandel',
#   ' importkontrakter',
#   ' kontrakter',
#   ' kontraktrett',
#   ' kontraktsrett',
#   ' kontraktsutforming',
#   ' norge',
#   ' vilkår'],
#  '2010071503020': ['sjørøveri'],
#  '2010072903013': ['nan'],
#  '2011030905027': ['fag',
#   ' fiskerifag',
#   ' lærebøker',
#   ' nautiske',
#   ' skole',
#   ' videregående'],
#  '2012101708094': ['arkeologi',
#   ' boplasser',
#   ' finnmark',
#   ' fornminner',
#   ' historie',
#   ' kulturminner',
#   ' lokalhistorie',
#   ' nesseby',
#   ' samer',
#   ' tilrettelegging'],
#  '2013121108221': ['nan'],
#  '2015052008090': ['gjeldsforhandlinger',
#   ' konkurs',
#   ' konkursboer',
#   ' konkurssaker',
#   ' norge',
#   ' skifterettsbehandling'],
#  '2016110948089': ['nan'],
#  '2017062307066': ['5.',
#   ' 5klasse',
#   ' 6-åringer',
#   ' grunnskolen',
#   ' klasse',
#   ' lærebok',
#   ' lærebøker',
#   ' læremiddel',
#   ' m87',
#   ' norsk',
#   ' norskfag',
#   ' rettskriving',
#   ' språk'],
#  '2007110804049': ['bhagavadgita',
#   ' filosofi',
#   ' hinduisme',
#   ' india',
#   ' religion',
#   ' østen']}
