# %% [markdown]
# # Undersøk korpus med metadata
#
# Notebook for å undersøke korpus med metadata

# %%
import dhlab.nbtext as nb
import dhlab.token_map as tm
import dhlab.graph_networkx_louvain as gnl
from dhlab.nbtext import Corpus
# %matplotlib inline

# %% [markdown]
# # Select a list of books

# %%
bøker = nb.book_urn({'title':'krig%', 'author':"tolst%",'year':1800, 'next':250, 'limit':30})

# %%
bøker
# Out:
# [[2008102200095, 'Tolstoj, L.N.', 'Krig og fred', 2000],
#  [2008101004071, 'Tolstoj, L.N.', 'Krig og fred', 2000],
#  [2008042400005, 'Tolstoj, L.N.', 'Krig og fred', 1951],
#  [2011063022004, 'Tolstoj, L.N.', 'Krig og fred', 1967],
#  [2012011008041, 'Tolstoj, L.N.', 'Krig og fred', 1951],
#  [2007041101090, 'Tolstoj, L.N.', 'Krig og fred', 1962],
#  [2011063022003, 'Tolstoj, L.N.', 'Krig og fred', 1967],
#  [2008102204034, 'Tolstoj, L.N.', 'Krig og fred', 2000],
#  [2015091406029, 'Tolstoj, L.N.', 'Krig og fred', 1929],
#  [2008110400150, 'Tolstoj, L.N.', 'Krig og fred', 2001],
#  [2007111900105, 'Tolstoj, L.N.', 'Krig og fred', 1993],
#  [2011061508082, 'Tolstoj, L.N.', 'Krig og fred', 2008],
#  [2011061508081, 'Tolstoj, L.N.', 'Krig og fred', 2008],
#  [2014100308012, 'Tolstoj, L.N.', 'Krig og fred', 1929],
#  [2007032601072, 'Tolstoj, L.N.', 'Krig og fred', 1962],
#  [2011063023001, 'Tolstoj, L.N.', 'Krig og fred', 1967],
# ...

# %% [markdown]
# ### Assign a select book to variable 'bok'

# %%
bok = bøker[0]

# %% [markdown]
# Compute the candidates for characters - anything starting with a capital letter that could be a person name or place name

# %%
bok_navn = tm.names(bok)

# %% [markdown]
# Edit the names, remove some words

# %%
tm.show_names(bok_navn)
# Out:
# Lag 1
# ...
#
#     Pierre - 687
#     De - 522
#     Natasja - 333
#     Maria - 275
#     Moskva - 207
#     Andrei - 196
#     Ja - 189
#     Nikolai - 180
#     Dem - 163
#     Petja - 161
#     Napoleon - 156
#     Deres - 145
#     Kutuzov - 138
#     Nei - 134
#     Alpatytsj - 104
#     Sonja - 96
#     Denisov - 90
#     Balasjov - 81
#     Gud - 71
#     Dolochov - 62
#     Rastoptsjin - 56
#     Nå - 54
#     Pierres - 54
#     Rostov - 52
#     Dron - 51
#     Helene - 46
#     Petersburg - 44
#     Rostovs - 41
#     Andreis - 33
#     Anna - 33
#     Borodino - 32
#     Russland - 32
#     Bourienne - 31
#     Desalles - 31
#     Davout - 30
#     Smolensk - 29
#     Gerasim - 28
#     Gory - 28
#     Vasilij - 28
#     Natasjas - 27
#     Lysye - 26
#     Pavlovna - 26
#     Bolkonskij - 25
#     Aleksander - 24
#     Benigsen - 23
#     Napoleons - 23
#     Veresjtsjagin - 23
#     Nikolais - 22
#     Beausset - 21
#     Marias - 20
#     Kutuzovs - 19
#     Bezuchov - 18
# ...

# %%
network = tm.make_network_name_graph(bok, bok_navn)

# %%
nb.central_betweenness_characters(network)
# Out:
# [('Deres_Napoleon', 0.2797632496337178),
#  ('Pierre_Bezuchov', 0.22879459988311152),
#  ('Andrei_Kutuzov', 0.16624486088179286),
#  ('Vet_De', 0.16288859002186218),
#  ('Moskva', 0.10688403679205694),
#  ('Natasja_Sonja', 0.07451897157088447),
#  ('Nikolai_Andreievitsj_Bolkonskijs', 0.055325098125310404),
#  ('Legg_Dem', 0.041288119729737296),
#  ('Maria_Dmitrievna', 0.037808131524394176),
#  ('Jakov_Alpatytsj', 0.03526248418987778)]

# %%
gnl.show_graph(network, spread=1.5)
# Out:
# D:\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
x = gnl.make_graph('regjering')

# %%
gnl.show_graph(x, spread=1.5)
# Out:
# D:\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
gnl.show_communities(x)
# Out:
# departement-departementer :  departement, departementer, forskningsråd, statsråder, direktorater, statsråd, politikere, etater, fylkesmann, underliggende, stortingsrepresentanter, institusjoner, sentraladministrasjon, virksomheter, direktorat
#
# regjering-storting :  regjering, storting, opposisjon, riksdag, fylkesting, kommunestyrer, stortingsflertall, storthing, kommunestyre, partiledelse, posisjon, regjeringer, kongehus, Sveriges, regjeringspartier, kritikk, Btorting, riksstyre, dens
#
# Storting-Regjering :  Storting, Regjering, styringsverk
#
# parti-stortingsgruppe :  parti, stortingsgruppe, fagbevegelse, organisasjonar, politikarar
#
# konge-Konge :  konge, Konge, dronning, Ess, keiser, kronprins, dame, fedreland, yppersteprest, knekt, Frelser, ess
#
# stat-fylke :  stat, fylke, individ, kirke, kommune, kyrkje, fylkeskommune, kommuner, fylker
#
# parlament-nasjonalforsamling :  parlament, nasjonalforsamling, president, forvaltning
