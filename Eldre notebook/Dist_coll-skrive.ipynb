# %% [markdown]
# # Data and computations for paper
#
# Lars G. Johnsen
# National Library of Norway

# %%
import dhlab.nbtext as nb
import dhlab.module_update as mu
mu.update('collocations')
from collocations import dist_coll_urn, urn_coll, calculate_midpoint, dist
import pandas as pd
# Out:
# Updated file `D:\Documents\GitHub\Oslomet\collocations.py`

# %%
def df_jaccard(df, col1, col2, number=100, asc=False):
    s1 = df.sort_values(by=col1, ascending=asc)[:number].index
    s2 = df.sort_values(by=col2, ascending=asc)[:number].index
    
    #print(len(set(s1)&set(s2)))
    
    return jaccard(s1, s2)

# %%
movealpha = lambda x: list(tuple([x[-1]]) + tuple(x[:-1]))

# %%
def jaccards(s1, s2):
    return len(set(s1)&set(s2)),len(set(s1)|set(s2))

# %%
def jaccard(s1, s2):
    return len(set(s1)&set(s2))/len(set(s1)|set(s2))

# %%
import pandas as pd

# %%
def make_dcoll_df(dists, norm, tot, exp=0):
    
    coll =  nb.frame(
        {
        'freq':dists['freq'].astype(int),
        'score':(dists.freq/dists.freq.sum())**exp*abs(norm/dists['2']), 
        'dist':dists['1'],
            'dist_' : dists['2'],
        'reference':(dists.freq/dists.freq.sum())/tot.tot
        }
    ).transpose()
    coll = coll.fillna(0)
    return coll.astype({'freq':'int32'})

# %% [markdown]
# ### Reference corpus
#
# The reference is the total counts from approximately 450 000 books from nb.no

# %%
tot = nb.frame(nb.totals(50000), 'tot')

# %%
nb.normalize_corpus_dataframe(tot)
tot.head()
# Out:
#           tot
# .    0.058921
# ,    0.051453
# og   0.025297
# i    0.021425
# det  0.012728

# %% [markdown]
# # Corpus
#
# The corpus for doing collocations is a sample of 800 books from fictional literature, dewey decimal code 813.

# %%
smd = 5
lmd = 10
collword = 'skrive'

# %%
def filenames(smd = smd, lmd = lmd, collword = collword, corpus_size= 1000, period = (1980, 2000)):
    return {
    'small_right': '_'.join([collword, str(smd), str(corpus_size), '-'.join([str(x) for x in period]), str(0), str(int(2*smd)), '.csv']),
    'large_right': '_'.join([collword, str(smd), str(corpus_size),  '-'.join([str(x) for x in period]), str(0), str(int(2*lmd)), '.csv']),
    'small_left' : '_'.join([collword, str(lmd), str(corpus_size),  '-'.join([str(x) for x in period]), str(int(2*smd)), str(0), '.csv']),
    'large_left' : '_'.join([collword, str(lmd), str(corpus_size),  '-'.join([str(x) for x in period]), str(int(2*lmd)), str(0), '.csv'])
        }

# %% [markdown]
# # Store the data subsequent use

# %%
names = filenames()
names
# Out:
# {'small_right': 'skrive_5_1000_1980-2000_0_10_.csv',
#  'large_right': 'skrive_5_1000_1980-2000_0_20_.csv',
#  'small_left': 'skrive_10_1000_1980-2000_10_0_.csv',
#  'large_left': 'skrive_10_1000_1980-2000_20_0_.csv'}

# %%
a1 = pd.read_csv(names['small_right'], index_col=0)
a2 = pd.read_csv(names['large_right'], index_col=0)
b1 = pd.read_csv(names['small_left'], index_col=0)
b2 = pd.read_csv(names['large_left'], index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-3d99ae6a5914> in <module>
# ----> 1 a1 = pd.read_csv(names['small_right'], index_col=0)
#       2 a2 = pd.read_csv(names['large_right'], index_col=0)
#       3 b1 = pd.read_csv(names['small_left'], index_col=0)
#       4 b2 = pd.read_csv(names['large_left'], index_col=0)
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# D:\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'skrive_5_1000_1980-2000_0_10_.csv' does not exist: b'skrive_5_1000_1980-2000_0_10_.csv'

# %% [markdown]
# ## Create collocation dataframe
#
# Based on data from a1 and a2, and b1 and b2. The name for the collocations after is `coll` while `collb` is for the collocates coming before.

# %%
coll = make_dcoll_df(a1, lmd, tot)

# %%
collb = make_dcoll_df(b1, lmd, tot)

# %% [markdown]
# ## Sorting
#
# Sorting on the reference is by column 'nb'

# %%
coll[coll.freq > 20].sort_values(by='score', ascending=False)[:20][:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow0_col0 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow0_col4 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow1_col0 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow1_col1 {
#             background-color:  #034f7d;
#             color:  #f1f1f1;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow1_col2 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow1_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow1_col4 {
#             background-color:  #88b1d4;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow2_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow2_col1 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow2_col2 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow2_col3 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow2_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow3_col0 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow3_col1 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow3_col2 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow3_col3 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow3_col4 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow4_col0 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow4_col1 {
#             background-color:  #84b0d3;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow4_col2 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow4_col3 {
#             background-color:  #a7bddb;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow4_col4 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow5_col0 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow5_col1 {
#             background-color:  #97b7d7;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow5_col2 {
#             background-color:  #93b5d6;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow5_col3 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow5_col4 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow6_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow6_col1 {
#             background-color:  #b1c2de;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow6_col2 {
#             background-color:  #7bacd1;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow6_col3 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow6_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow7_col1 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow7_col2 {
#             background-color:  #86b0d3;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow7_col3 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow7_col4 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow8_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow8_col1 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow8_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow8_col3 {
#             background-color:  #4e9ac6;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow8_col4 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow9_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow9_col1 {
#             background-color:  #cccfe5;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow9_col2 {
#             background-color:  #5a9ec9;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow9_col3 {
#             background-color:  #4a98c5;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow9_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow10_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow10_col1 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow10_col2 {
#             background-color:  #549cc7;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow10_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow10_col4 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow11_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow11_col1 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow11_col2 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow11_col3 {
#             background-color:  #4295c3;
#             color:  #000000;
#         }    #T_fa71df40_51f0_11ea_be01_7c7635c6d85arow11_col4 {
#             background-color:  #91b5d6;
#             color:  #0

# %%
coll.sort_values(by='reference', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow0_col0 {
#             background-color:  #9fbad9;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow0_col1 {
#             background-color:  #60a1ca;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow0_col2 {
#             background-color:  #e0dded;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow0_col3 {
#             background-color:  #dfddec;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow0_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow1_col0 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow1_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow1_col2 {
#             background-color:  #0566a0;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow1_col3 {
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow1_col4 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow2_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow2_col1 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow2_col2 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow2_col3 {
#             background-color:  #a2bcda;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow2_col4 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow3_col0 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow3_col1 {
#             background-color:  #056dac;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow3_col2 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow3_col3 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow3_col4 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow4_col0 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow4_col1 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow4_col2 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow4_col3 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow4_col4 {
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow5_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow5_col1 {
#             background-color:  #045788;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow5_col2 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow5_col3 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow5_col4 {
#             background-color:  #3f93c2;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow6_col0 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow6_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow6_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow6_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow6_col4 {
#             background-color:  #6ba5cd;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow7_col0 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow7_col1 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow7_col2 {
#             background-color:  #2484ba;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow7_col3 {
#             background-color:  #2081b9;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow7_col4 {
#             background-color:  #a1bbda;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow8_col0 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow8_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow8_col2 {
#             background-color:  #0567a2;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow8_col3 {
#             background-color:  #0567a1;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow8_col4 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow9_col0 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow9_col1 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow9_col2 {
#             background-color:  #b9c6e0;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow9_col3 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow9_col4 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow10_col0 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow10_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow10_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow10_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow10_col4 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow11_col0 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow11_col1 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow11_col2 {
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow11_col3 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_beda38d2_51e6_11ea_8849_7c7635c6d85arow11_col4 {
#             background-color:  #f0eaf4;
#             color:  #0

# %%
coll.loc[[',','.', 'og','eller', 'i', 'på','ned']]

# %% [markdown]
# # collb

# %%
collb.sort_values(by='nb', ascending=False)[:20].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_df0065ac_5184_11ea_8900_7c7635c6d85arow0_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow1_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow1_col1 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow1_col2 {
#             background-color:  #529bc7;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow1_col3 {
#             background-color:  #0a73b2;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow2_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow2_col1 {
#             background-color:  #05659f;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow2_col2 {
#             background-color:  #04629a;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow2_col3 {
#             background-color:  #2685bb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow3_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow3_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow3_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow3_col3 {
#             background-color:  #3b92c1;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow4_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow4_col1 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow4_col2 {
#             background-color:  #a9bfdc;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow4_col3 {
#             background-color:  #4496c3;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow5_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow5_col1 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow5_col2 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow5_col3 {
#             background-color:  #7dacd1;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow6_col1 {
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow6_col2 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow6_col3 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow7_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow7_col1 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow7_col2 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow7_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow8_col0 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow8_col1 {
#             background-color:  #e8e4f0;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow8_col2 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow8_col3 {
#             background-color:  #c6cce3;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow9_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow9_col1 {
#             background-color:  #abbfdc;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow9_col2 {
#             background-color:  #4094c3;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow9_col3 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow10_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow10_col1 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow10_col2 {
#             background-color:  #eee9f3;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow10_col3 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow11_col1 {
#             background-color:  #045280;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow11_col3 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow12_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow12_col1 {
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow12_col2 {
#             background-color:  #80aed2;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow12_col3 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow13_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow13_col1 {
#             background-color:  #c1cae2;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow13_col2 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow13_col3 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow14_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow14_col1 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow14_col2 {
#             background-color:  #e2dfee;
#             color:  #000000;
#         }    #T_df0065ac_5184_11ea_8900_7c7635c6d85arow14_col3 {
#             background-color:  #ede7f2;

# %%
collb.sort_values(by='score', ascending=False)[:40].fillna(0).style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow0_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow0_col2 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow0_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow0_col4 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow1_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow1_col1 {
#             background-color:  #328dbf;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow1_col2 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow1_col3 {
#             background-color:  #0d75b3;
#             color:  #f1f1f1;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow1_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow2_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow2_col1 {
#             background-color:  #3790c0;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow2_col2 {
#             background-color:  #83afd3;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow2_col3 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow2_col4 {
#             background-color:  #ede7f2;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow3_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow3_col1 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow3_col2 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow3_col3 {
#             background-color:  #4c99c5;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow3_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow4_col1 {
#             background-color:  #81aed2;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow4_col2 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow4_col3 {
#             background-color:  #509ac6;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow4_col4 {
#             background-color:  #e9e5f1;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow5_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow5_col1 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow5_col2 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow5_col3 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow5_col4 {
#             background-color:  #f1ebf5;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow6_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow6_col1 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow6_col2 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow6_col3 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow6_col4 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow7_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow7_col1 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow7_col2 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow7_col3 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow7_col4 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow8_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow8_col1 {
#             background-color:  #a8bedc;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow8_col2 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow8_col3 {
#             background-color:  #7eadd1;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow8_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow9_col0 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow9_col1 {
#             background-color:  #b0c2de;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow9_col2 {
#             background-color:  #c2cbe2;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow9_col3 {
#             background-color:  #89b1d4;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow9_col4 {
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow10_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow10_col1 {
#             background-color:  #b7c5df;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow10_col2 {
#             background-color:  #3991c1;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow10_col3 {
#             background-color:  #91b5d6;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow10_col4 {
#             background-color:  #034267;
#             color:  #f1f1f1;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow11_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow11_col1 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow11_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow11_col3 {
#             background-color:  #99b8d8;
#             color:  #000000;
#         }    #T_eca02368_51e6_11ea_a3d2_7c7635c6d85arow11_col4 {
#             background-color:  #fdf5fa;
#             color:  #0

# %%
common = coll.loc[[',','.', 'og','eller', 'i', 'på']]

# %%
common['translate'] = [',', '.', 'and', 'or', 'in', 'on']

common = common[movealpha(common.columns)]

# %%
common
# Out:
#       translate  freq     score      dist  dist_  reference
# ,             ,  2649  1.858736  5.378655   5.38   0.753565
# .             .  3757  1.876173  5.326698   5.33   0.933303
# og          and  1671  1.855288  5.389590   5.39   0.966833
# eller        or   342  2.066116  4.840187   4.84   1.823320
# i            in  1235  1.739130  5.754632   5.75   0.843717
# på           on  1080  2.136752  4.681068   4.68   1.648530

# %%
top10ratio = coll.sort_values(by='score', ascending=False)[:10]

# %%
top10ratio.index
# Out:
# Index(['referat', 'ned', 'dikt', 'kjærlighetsbrev', 'søknader', 'hovedoppgave',
#        'postnavnet', 'låter', 'programmene', 'romaner'],
#       dtype='object')

# %%
top10ratio['translate'] = ['minutes', 'down', 'poems', 'love letters', 'applications', 'master thesis',
       'postal name', 'songs', 'programs', 'novels']

# %%
top10ratio  = top10ratio[movealpha(top10ratio.columns)]

# %%
top10ratio
# Out:
#                      translate  freq     score      dist  dist_  reference
# referat                minutes     7  6.097561  1.000000   1.64  21.736460
# ned                       down   313  5.747126  1.729599   1.74   7.169013
# dikt                     poems    72  5.494505  1.772565   1.82  38.933198
# kjærlighetsbrev   love letters     7  5.263158  1.300000   1.90   0.000000
# søknader          applications     5  5.263158  1.000000   1.90  12.992538
# hovedoppgave     master thesis     8  5.263158  1.388889   1.90  34.394171
# postnavnet         postal name     5  5.263158  1.000000   1.90   0.000000
# låter                    songs    14  5.181347  1.653846   1.93  77.985702
# programmene           programs     5  5.076142  1.083333   1.97  16.092123
# romaner                 novels    10  4.975124  1.625000   2.01  19.599639

# %% [markdown]
# # coll

# %% [markdown]
# # jaccard similarity
#
# compare over a range

# %%
rng = range(2,40,2)

# %% [markdown]
# # for collb

# %%
jaccard_scoresb = nb.frame({'ratio': {x:df_jaccard(collb, 'reference', 'score', x) for x in rng}
                            }).transpose()

# %%
ax = jaccard_scoresb['ratio'].plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")
# Out:
# Text(0, 0.5, 'Jaccard score')

# %% [markdown]
# # for coll

# %%
jaccard_scores = nb.frame({'ratio': {x:df_jaccard(coll[coll.freq > 20], 'score', 'reference', x) for x in rng}     }).transpose()

# %%
ax = jaccard_scores['ratio'].plot(title='compared to reference corpus');
ax.set_xlabel("Number of words")
ax.set_ylabel("Jaccard score")
# Out:
# Text(0, 0.5, 'Jaccard score')

# %%
coll.loc[coll[coll.score > 4].index].sort_values(by='score', ascending=False)
# Out:
#                  freq     score      dist  dist_  reference
# referat             7  6.097561  1.000000   1.64  21.736460
# ned               313  5.747126  1.729599   1.74   7.169013
# dikt               72  5.494505  1.772565   1.82  38.933198
# kjærlighetsbrev     7  5.263158  1.300000   1.90   0.000000
# postnavnet          5  5.263158  1.000000   1.90   0.000000
# søknader            5  5.263158  1.000000   1.90  12.992538
# hovedoppgave        8  5.263158  1.388889   1.90  34.394171
# låter              14  5.181347  1.653846   1.93  77.985702
# programmene         5  5.076142  1.083333   1.97  16.092123
# romaner            10  4.975124  1.625000   2.01  19.599639
# artikkelen         14  4.950495  1.755556   2.02  14.929763
# @                   5  4.854369  1.200000   2.06   2.117575
# enkle               5  4.807692  1.222222   2.08   1.871141
# dagbok             32  4.739336  2.004074   2.11  83.950795
# kontrakt           11  4.672897  1.805556   2.14  13.602895
# testamente         13  4.629630  1.883333   2.16  23.087654
# adresselapper       6  4.608295  1.500000   2.17   0.000000
# verdien            10  4.566210  1.825000   2.19   4.944944
# stikkord            8  4.484305  1.766667   2.23  23.820469
# verdier             8  4.424779  1.791667   2.26   2.473915
# innlegg             8  4.366812  1.833333   2.29  13.783790
# søknaden            5  4.347826  1.500000   2.30  10.678603
# talene              4  4.329004  1.250000   2.31   0.000000
# avhandlingen        6  4.329004  1.666667   2.31  21.154793
# navnet             85  4.273504  2.307142   2.34  15.893534
# memoarer            8  4.273504  1.888889   2.34  95.072102
# lapper              8  4.184100  1.944444   2.39  44.532489
# under             183  4.184100  2.368012   2.39   2.834007
# talen               5  4.166667  1.625000   2.40   8.148274
# noget               6  4.132231  1.800000   2.42   0.647091
# forord              5  4.115226  1.666667   2.43  34.883643
# skuespill          10  4.115226  2.092593   2.43  18.791631
# utførlig            7  4.081633  1.944444   2.45  21.585110
# navnene             9  4.065041  2.083333   2.46  12.238384
# brev              228  4.048583  2.452302   2.47  41.207082
# artikler           18  4.048583  2.288889   2.47  16.737068

# %%
coll.loc[coll[coll.reference> 30].index].sort_values(by='reference', ascending=False)
# Out:
#               freq     score      dist  dist_   reference
# resept          15  3.424658  2.731481   2.92  110.160418
# diktat           7  1.584786  6.444444   6.31   97.514087
# stiler          10  2.500000  3.833333   4.00   96.669498
# memoarer         8  4.273504  1.888889   2.34   95.072102
# selvbiografi     7  2.801120  3.250000   3.57   86.367543
# dagbok          32  4.739336  2.004074   2.11   83.950795
# låter           14  5.181347  1.653846   1.93   77.985702
# tastaturet      10  1.782531  5.620370   5.61   69.623615
# skrivemaskin     7  1.597444  6.388889   6.26   68.360110
# redigere         9  2.659574  3.541667   3.76   58.568307
# skriveren        8  1.366120  7.583333   7.32   50.763192
# poesi           20  3.076923  3.133333   3.25   50.536780
# sammendrag      11  3.048780  3.055556   3.28   50.352297
# lapp            18  2.702703  3.592593   3.70   50.166994
# tavla           12  1.886792  5.277778   5.30   49.718362
# opprop           4  2.024291  4.750000   4.94   47.854381
# reserverte       4  3.636364  1.833333   2.75   46.803693
# lapper           8  4.184100  1.944444   2.39   44.532489
# prosa            9  3.300330  2.722222   3.03   44.163882
# poesien          5  1.620746  6.333333   6.17   43.703223
# notatet          8  2.141328  4.555556   4.67   43.420177
# biografi         9  3.717472  2.333333   2.69   43.259877
# blankett         3  1.715266  6.000000   5.83   42.472945
# Skrive           6  2.100840  4.611111   4.76   42.423280
# gardin           3  1.715266  6.000000   5.83   42.259828
# årstallet        3  1.620746  6.500000   6.17   41.472043
# RAM              3  1.715266  6.000000   5.83   41.254390
# brev           228  4.048583  2.452302   2.47   41.207082
# essays           6  3.773585  2.083333   2.65   39.986504
# konsumet         3  2.118644  4.333333   4.72   39.847990
# arkene           5  1.569859  6.583333   6.37   39.352592
# dikt            72  5.494505  1.772565   1.82   38.933198
# marg             7  2.000000  4.916667   5.00   38.890880
# besvarelsen      3  2.118644  4.333333   4.72   38.163273
# bokstaver       30  2.314815  4.275463   4.32   38.124712
# roman           31  3.584229  2.698611   2.79   37.191153
# makro            3  1.314060  8.666667   7.61   36.313583
# exit             3  4.000000  1.000000   2.50   35.889420
# Shakespeares     4  3.205128  2.333333   3.12   35.530506
# arket           15  2.044990  4.847222   4.89   35.251004
# forord           5  4.115226  1.666667   2.43   34.883643
# tilståelse       4  3.076923  2.500000   3.25   34.850199
# kalenderen       4  2.164502  4.333333   4.62   34.800056
# hovedoppgave     8  5.263158  1.388889   1.90   34.394171
# dagbøker         3  1.488095  7.333333   6.72   33.822712
# dokumentet      29  2.617801  3.764550   3.82   33.820789
# rosende          3  3.745318  1.250000   2.67   33.453262
# Tesman           5  1.901141  5.200000   5.26   33.265680
# markøren         7  1.666667  6.083333   6.00   31.281398
# arbeidsboka      4  2.049180  4.666667   4.88   31.200914
# WITH             3  2.463054  3.333333   4.06   30.931323
# tavlen           5  2.702703  3.250000   3.70   30.854026
# maskin          29  3.086420  3.162500   3.24   30.785088

# %%
set(coll[coll.nb > 30].index) & set(coll[coll.score > 3.5].index)
# Out:
# {'biografi',
#  'brev',
#  'dagbok',
#  'dikt',
#  'essays',
#  'exit',
#  'forord',
#  'hovedoppgave',
#  'lapper',
#  'låter',
#  'memoarer',
#  'reserverte',
#  'roman',
#  'rosende'}
