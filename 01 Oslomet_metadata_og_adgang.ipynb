# %% [markdown]
# # Oslomet - Om kunnskap og informasjon
#
# * Lars G. Johnsen
# * lars.johnsen@nb.no
# * Nasjonalbiblioteket
# * Oktober 2020

# %% [markdown]
# Importer ressurser

# %%
import dhlab.module_update as mu
import dhlab.nbtext as nb
import dhlab.nbpictures as pct

# %%
mu.css()
# Out:
# <style>@import url(
# http://fonts.googleapis.com/css?family=Lato|Philosopher|Montserrat|Source+Code+Pro|Istok+Web|Philosopher|Assistant:200,400,700);
#
# /*
# #notebook-container {
# 	-webkit-box-shadow: none;
# 	box-shadow: none;
# }
# */
#
# h1, h2, h3, h4, h5, h6 {
# 	font-family: 'Montserrat', sans-serif;
# 	line-height: 2em;
#     color: #004f99;
#     font-weight: 600;
# }
#
# h1 { font-size: 4.5em; }
# h2 { font-size: 4em; }
# h3 { font-size: 3.5em; }
# h4 { font-size: 3em; }
# h5 { font-size: 2.5em; color:DarkSlateGray; }
# h6 { font-size: 2em; }
#
# p {
# 	font-family: 'Assistant', sans-serif;
# 	font-size: 1.2em;
# 	line-height: 1.4em;
# 	color: black;
# }
# p code {
# 	font-size:0.9em;
# }
# div.input_area {
# 	border:none !important;
# 	border-left:1px solid #ff851b !important
# }
#
# span.cm-keyword {
# 	color:#339966 !important;
# }
# span.nn {  /*span.cm-variable, span.cm-property*/
# 	color: #3399ff !important;
# }
# div.CodeMirror {
# 	font-family: 'Inconsolata', monospace;
# 	font-size: 1.1em;
#
# }
# </style>

# %% [markdown]
# # Nasjonalbiblioteket og digitalisering
#
# * Digitaliseringsarbeidet startet for alvor i 2006
# * Metadata for bøker fra Nasjonalbibliografien, og nye metadataformat for nye medier, som film og lyd.
# * Bokhylla-avtalen fra 2012. Alle bøker publisert før 2000 er tilgjengelig på [nb.no](https://www.nb.no)
# * Fra 2017 er bøkene også gjort tilgjengelig for forskning gjennom ikke-konsumerbar bruk
#
# * Håndskrift og brev
#
# * Samarbeid med NeIC
#
# Lenker til bildetjeneste
#
# https://share.streamlit.io/yoonsen/illustrations_bokhylla/illustration_st.py

# %% [markdown]
# # Metadata for objekter
#
# Metadata er informasjon om objekter, og
# i seg selv et resultat av resonnementer. Metadata kan kombineres og kobles til seg selv, og kobles til innhold for å gi ny kunnskap og informasjon.
#
# Metadata legges inn ved bibliotekene i forskjellige formater, for eksempel Marc21, og kan hentes ut fra digitale lager. For eksempel med [APIer](https://api.nb.no) fra Nasjonalbiblioteket. APIene er adgang til metadata for programmer og algoritmer, og brukes til å bygge brukergrensesnitt, som for eksempel [ORIA](https://oria.no)

# %% [markdown]
# ### API
# ### HTTP
#
# ### HTML

# %% [markdown]
# ### Språkbankens API mot metadata

# %% [markdown]
# ## URN (Universal Resource Name)
#
#
# * bøker: URN:NBN:no-nb_digibok_2008053000044
#
# * brev: URN:NBN:no-nb_digimanus_241993
#
# DOI - også et system for referanse.

# %%
korpus = nb.book_corpus(author = "hamsun%knut%", period=(1870, 1910), limit=100)

# %%
korpus
# Out:
#               urn        author                                  title  year
# 0   2016011129002  Hamsun, Knut                        Dronning Tamara  1903
# 1   2009060913006  Hamsun, Knut                                   Rosa  1908
# 2   2008122910001  Hamsun, Knut                               Kratskog  1903
# 3   2009042803003  Hamsun, Knut                         Redaktør Lynge  1893
# 4   2008090113002  Hamsun, Knut                           Livets Under  1910
# 5   2009061013011  Hamsun, Knut                                Bjørger  1878
# 6   2009042313001  Hamsun, Knut                           Lars Oftedal  1889
# 7   2009061013012  Hamsun, Knut                                gjensyn  1878
# 8   2009051813003  Hamsun, Knut                          Stridende Liv  1905
# 9   2008123012003  Hamsun, Knut                         Redaktør Lynge  1893
# 10  2008122910003  Hamsun, Knut                     Under Høststjærnen  1906
# 11  2009050810001  Hamsun, Knut                               Sværmere  1904
# 12  2009061012004  Hamsun, Knut      Fra det moderne Amerikas Aandsliv  1889
# 13  2009051513003  Hamsun, Knut                                 Siesta  1897
# 14  2008122912002  Hamsun, Knut                           Munken Vendt  1902
# 15  2015021824001  Hamsun, Knut  Sklaven der Liebe und andere Novellen  1902
# 16  2008123010003  Hamsun, Knut                        Ved Rigets Port  1895
# 17  2008082710002  Hamsun, Knut                                    Pan  1894
# 18  2008123012002  Hamsun, Knut                              Mysterier  1892
# 19  2008122912001  Hamsun, Knut                          I Æventyrland  1903
# 20  2008123010001  Hamsun, Knut                            Livet ivold  1910
# 21  2008123010002  Hamsun, Knut                                Ny Jord  1893
# 22  2014120208258  Hamsun, Knut                                   Sult  1899
# 23  2013040824080  Hamsun, Knut                                 Benoni  1908
# 24  2008112113001  Hamsun, Knut                             Gaadefulde  1877
# 25  2009010210001  Hamsun, Knut                            Livets Spil  1896
# 26  2009051813001  Hamsun, Knut                          Det vilde Kor  1904
# 27  2007060512003  Hamsun, Knut                              Aftenrøde  1898
# 28  2015051929001  Hamsun, Knut                                   Sult  1890
# 29  2016111748539  Hamsun, Knut                             Oplevelser  1897
# 30  2009050610002  Hamsun, Knut                               Victoria  1898
# 31  2009061903032  Hamsun, Knut             Vandrer spiller med Sordin  1909

# %%
urnlist = list(korpus['urn'])
urnlist
# Out:
# [2016011129002,
#  2009060913006,
#  2008122910001,
#  2009042803003,
#  2008090113002,
#  2009061013011,
#  2009042313001,
#  2009061013012,
#  2009051813003,
#  2008123012003,
#  2008122910003,
#  2009050810001,
#  2009061012004,
#  2009051513003,
#  2008122912002,
#  2015021824001,
#  2008123010003,
#  2008082710002,
#  2008123012002,
#  2008122912001,
#  2008123010001,
#  2008123010002,
#  2014120208258,
#  2013040824080,
#  2008112113001,
#  2009010210001,
#  2009051813001,
#  2007060512003,
#  2015051929001,
#  2016111748539,
#  2009050610002,
#  2009061903032]

# %% [markdown]
# ### NBs api mot metadata som marc-xml

# %%
nb.xmlpretty(nb.metadata_xml(2014120208258))
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <html>
#  <body>
#   <record xmlns="http://www.loc.gov/MARC21/slim">
#    <leader>
#     nam  22     uu 4500
#    </leader>
#    <controlfield tag="001">
#     990509919064702202
#    </controlfield>
#    <controlfield tag="003">
#     nb.bibsys.no
#    </controlfield>
#    <controlfield tag="005">
#     20150125121052.0
#    </controlfield>
#    <controlfield tag="008">
#     150125s        xx#||||| |||||||||||nob||
#    </controlfield>
#    <datafield ind1=" " ind2=" " tag="040">
#     <subfield code="a">
#      NO-OsNB
#     </subfield>
#    </datafield>
#    <datafield ind1="1" ind2="0" tag="245">
#     <subfield code="a">
#      Sult
#     </subfield>
#     <subfield code="c">
#      Knut Hamsun
#     </subfield>
#    </datafield>
#    <datafield ind1="1" ind2=" " tag="700">
#     <subfield code="a">
#      Hamsun, Knut
#     </subfield>
#     <subfield code="d">
#      1859-1952
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2="7" tag="655">
#     <subfield code="a">
#      unknown
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="250">
#     <subfield code="a">
#      2. Opl.
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="260">
#     <subfield code="a">
#      Kristiania
#     </subfield>
#     <subfield code="b">
#      Cammermeyer
#     </subfield>
#     <subfield code="c">
#      1899
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="300">
#     <subfield code="a">
#      310 s.
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="">
#     <subfield code="a">
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="500">
#     <subfield code="a">
#      Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2015-01-25
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="856">
#     <subfield code="u">
#      http://urn.nb.no/URN:NBN:no-nb_digibok_2014120208258
#     </subfield>
#     <subfield code="3">
#      Fulltekst NB digitalisert
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="856">
#     <subfield code="u">
#      http://urn.nb.no/URN:NBN:no-nb_digibok_2014120208258
#     </subfield>
#     <subfield code="3">
#      electronic resource
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="852">
#     <subfield code="a">
#      NO-0030100
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="852">
#     <subfield code="a">
#      NO-0183300
#     </subfield>
#    </datafield>
#    <datafield ind1=" " ind2=" " tag="856">
#     <subfield code="u">
#      http://urn.nb.no/URN:NBN:no-nb_digibok_2014120208258
#     </subfield>
#    </datafield>
#   </record>
#  </body>
# </html>

# %% [markdown]
# ### Informasjon om Dewey-systemet
#
# Her er lenke til [Webdewey](http://deweysearchno.pansoft.de/webdeweysearch/index.html), ellers er det litt informasjon for programmet.

# %%
nb.dewey(839)
# Out:
# {'1': ['8', 'Litteratur'],
#  '2': ['83', 'Tysk og beslektede litteraturer'],
#  '3': ['839', 'Andre germanske språks litteraturer']}

# %% [markdown]
# Vi kan se på konkordanser, eller "keyword in context" (KWIC)

# %%
nb.urn_concordance(word = 'gror', urns = urnlist, before = 12, after = 12)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011129002?searchText=gror' target='_blank' style='text-decoration:none'>Dronning Tamara, Hamsun, Knut, 1903</a>
#                 </td>
#                 <td>Der staar den og</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>i det farlige Krat i Simlas og Vindhyas Fjælde .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011129002?searchText=gror' target='_blank' style='text-decoration:none'>Dronning Tamara, Hamsun, Knut, 1903</a>
#                 </td>
#                 <td>i Krattet hvor Alrunerne</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>. Det er farlige Blomster , de gør alt noget ved mig</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051813003?searchText=gror' target='_blank' style='text-decoration:none'>Stridende Liv, Hamsun, Knut, 1905</a>
#                 </td>
#                 <td>« Den syge Mand » er spillevende , han sidder blot og</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>sig større og øger sin Kraft . De tre mægtige Herrer i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009061012004?searchText=gror' target='_blank' style='text-decoration:none'>Fra det moderne Amerikas Aandsliv, Hamsun, Knut, 1889</a>
#                 </td>
#                 <td>, som lægger Landskaber øde , men i hvis Spor der atter</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>Græs engang . Men i Amerikanernes Samtaler, i Tonen i deres Aviser</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008122912002?searchText=gror' target='_blank' style='text-decoration:none'>Munken Vendt, Hamsun, Knut, 1902</a>
#                 </td>
#                 <td>Det vaagner og vokser og</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>allevegne fra Myrenes Mose til Urenes Bregne ■ — slig skyder den</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2013040824080?searchText=gror' target='_blank' style='text-decoration:none'>Benoni, Hamsun, Knut, 1908</a>
#                 </td>
#                 <td>For Pigen brænder og braser saa Rørene</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>igen . Skal du bli her ?</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051813001?searchText=gror' target='_blank' style='text-decoration:none'>Det vilde Kor, Hamsun, Knut, 1904</a>
#                 </td>
#                 <td>I Der staar den og</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>45</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051813001?searchText=gror' target='_blank' style='text-decoration:none'>Det vilde Kor, Hamsun, Knut, 1904</a>
#                 </td>
#                 <td>Der staar den og</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>None</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051813001?searchText=gror' target='_blank' style='text-decoration:none'>Det vilde Kor, Hamsun, Knut, 1904</a>
#                 </td>
#                 <td>Der staar den og</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>i det farlige Krat i Simlas og Vindhyas Fjælde .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060512003?searchText=gror' target='_blank' style='text-decoration:none'>Aftenrøde, Hamsun, Knut, 1898</a>
#                 </td>
#                 <td>. Jeg sidder her og tænker og læser hele Tiden , jeg</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2007060512003?searchText=gror' target='_blank' style='text-decoration:none'>Aftenrøde, Hamsun, Knut, 1898</a>
#                 </td>
#                 <td>staar ikke længer fast i min Forhærdelse, jeg vejer , vrager og</td>
#                 <td>gror</td>
#                 <td style='text-align:left'>. Jeg finder ingen Modsigelse i , at jeg for tyve Aar</td>
#             </tr>
# </table>

# %%
nb.urn_concordance(word = 'Krat', urns = urnlist, before = 12, after = 12)
# Out:
# <table><tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2016011129002?searchText=Krat' target='_blank' style='text-decoration:none'>Dronning Tamara, Hamsun, Knut, 1903</a>
#                 </td>
#                 <td>Der staar den og gror i det farlige</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>i Simlas og Vindhyas Fjælde .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008122910001?searchText=Krat' target='_blank' style='text-decoration:none'>Kratskog, Hamsun, Knut, 1903</a>
#                 </td>
#                 <td>skænkte fuldt i Glassene og dråk . Men langt bagenfor det lave</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>ved Stranden maatte vel Andrea og Rorskarn gaa og finde SjøfuglÆg, for</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009042803003?searchText=Krat' target='_blank' style='text-decoration:none'>Redaktør Lynge, Hamsun, Knut, 1893</a>
#                 </td>
#                 <td>der forsvandt hun ! Og Højbro stirred et Øjeblik endnu paa det</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>, der havde skjult hende ; han vred Hænderne stille og haardt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008123012003?searchText=Krat' target='_blank' style='text-decoration:none'>Redaktør Lynge, Hamsun, Knut, 1893</a>
#                 </td>
#                 <td>der forsvandt hun ! Og Højbro stirred et Øjeblik endnu paa det</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>, der havde skjult hende ; han vred Hænderne stille og haardt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008122912002?searchText=Krat' target='_blank' style='text-decoration:none'>Munken Vendt, Hamsun, Knut, 1902</a>
#                 </td>
#                 <td>. Og nu er jeg fri . Som en Ulv i sit</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>.</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008122912002?searchText=Krat' target='_blank' style='text-decoration:none'>Munken Vendt, Hamsun, Knut, 1902</a>
#                 </td>
#                 <td>før Natten er omme . Du skjuler dig der i det tykkeste</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>, og ser du ham , mjauer du gnelt som en Kat</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082710002?searchText=Krat' target='_blank' style='text-decoration:none'>Pan, Hamsun, Knut, 1894</a>
#                 </td>
#                 <td>og Hængetiter og en og anden Jærnspurv lever alene i Urer og</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>; pip-pip ! Alt er saa underlig forandret , Dværgbirken bløder rødt</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008082710002?searchText=Krat' target='_blank' style='text-decoration:none'>Pan, Hamsun, Knut, 1894</a>
#                 </td>
#                 <td>Saa forsvandt han et Øjeblik bag et</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>. Hvor det skulde være mig en Fryd at skyde ham ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008122912001?searchText=Krat' target='_blank' style='text-decoration:none'>I Æventyrland, Hamsun, Knut, 1903</a>
#                 </td>
#                 <td>overklædt med den frodigste Vegetation . Det er ingen Skog , men</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>, tildels højt Krat af Løvtræer . Her er i forskellig Højde</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008122912001?searchText=Krat' target='_blank' style='text-decoration:none'>I Æventyrland, Hamsun, Knut, 1903</a>
#                 </td>
#                 <td>Vegetation . Det er ingen Skog , men Krat , tildels højt</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>af Løvtræer . Her er i forskellig Højde Eg , Kastanje ,</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008122912001?searchText=Krat' target='_blank' style='text-decoration:none'>I Æventyrland, Hamsun, Knut, 1903</a>
#                 </td>
#                 <td>er ikke længere det snaue Fjæld , her er lidt Løvkrat og</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>af store Bregner hist og her . Da jeg har redet i</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2008123010002?searchText=Krat' target='_blank' style='text-decoration:none'>Ny Jord, Hamsun, Knut, 1893</a>
#                 </td>
#                 <td>Det var ganske sandt et stille Sted , et rent</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>, nogle store Stene , Ener , Lyng , indelukket til to</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051813001?searchText=Krat' target='_blank' style='text-decoration:none'>Det vilde Kor, Hamsun, Knut, 1904</a>
#                 </td>
#                 <td>med Fjær i sin Hat og Hundene halser i Snar og i</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>og Nypen staar bar med sin Torn . Selv trællende Heste som</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009051813001?searchText=Krat' target='_blank' style='text-decoration:none'>Det vilde Kor, Hamsun, Knut, 1904</a>
#                 </td>
#                 <td>Der staar den og gror i det farlige</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>i Simlas og Vindhyas Fjælde .</td>
#             </tr>
# <tr>
#                 <td>
#                     <a href='http://www.nb.no/items/URN:NBN:no-nb_digibok_2009050610002?searchText=Krat' target='_blank' style='text-decoration:none'>Victoria, Hamsun, Knut, 1898</a>
#                 </td>
#                 <td>« Her ved dette</td>
#                 <td>Krat</td>
#                 <td style='text-align:left'>har engang hændt mig noget . Jeg kom gaaende en Aften ,</td>
#             </tr>
# </table>
